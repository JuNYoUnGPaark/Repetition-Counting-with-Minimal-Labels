# %%
# =========================
# Step Counter for Baseline (epoch-based) training
# - Computes "original" total optimizer steps when epochs=100
# - For BOTH training modes:
#   (1) trial_only        : train samples = trials
#   (2) ours_window_proxy : train samples = windows (win_sec/stride_sec)
# - LOSO per activity, per fold
# =========================

import os, glob, random
import numpy as np
import pandas as pd

import torch
from torch.utils.data import Dataset, DataLoader


# ---------------------------------------------------------------------
# 1) Strict Seeding
# ---------------------------------------------------------------------
def set_strict_seed(seed: int):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


# ---------------------------------------------------------------------
# 2) Data Loading
# ---------------------------------------------------------------------
def load_mhealth_dataset(data_dir, target_activities_map, column_names):
    full_dataset = {}
    file_list = sorted(glob.glob(os.path.join(data_dir, "mHealth_subject*.log")))
    if not file_list:
        print(f"[Warning] No mHealth logs found in {data_dir}")
        return {}

    print(f"Loading {len(file_list)} subjects from {data_dir}...")
    for file_path in file_list:
        file_name = os.path.basename(file_path)
        subj_part = file_name.split('.')[0]
        try:
            subj_id_num = int(''.join(filter(str.isdigit, subj_part)))
            subj_key = f"subject{subj_id_num}"
        except:
            subj_key = subj_part

        try:
            df = pd.read_csv(file_path, sep="\t", header=None)
            df = df.iloc[:, :len(column_names)]
            df.columns = column_names

            subj_data = {}
            for label_code, activity_name in target_activities_map.items():
                activity_df = df[df['activity_id'] == label_code].copy()
                if not activity_df.empty:
                    subj_data[activity_name] = activity_df.drop(columns=['activity_id'])

            full_dataset[subj_key] = subj_data
        except Exception as e:
            print(f"Error loading {file_name}: {e}")
            pass

    return full_dataset


def prepare_trial_list(label_config, full_data, target_map, feature_map):
    trial_list = []
    for subj, act_id, gt_count in label_config:
        act_name = target_map.get(act_id)
        feats = feature_map.get(act_id)

        if subj in full_data and act_name in full_data[subj]:
            raw_df = full_data[subj][act_name][feats]
            raw_np = raw_df.values.astype(np.float32)

            mean = raw_np.mean(axis=0)
            std = raw_np.std(axis=0) + 1e-6
            norm_np = (raw_np - mean) / std

            trial_list.append({
                'data': norm_np,              # (T, C)
                'count': float(gt_count),
                'meta': f"{subj}_{act_name}"
            })
        else:
            print(f"[Skip] Missing data for {subj} - {act_name}")

    return trial_list


# ---------------------------------------------------------------------
# 2.5) Windowing
# ---------------------------------------------------------------------
def trial_list_to_windows(trial_list, fs, win_sec=8.0, stride_sec=4.0, drop_last=True):
    win_len = int(round(win_sec * fs))
    stride = int(round(stride_sec * fs))
    assert win_len > 0 and stride > 0

    windows = []
    for item in trial_list:
        x = item["data"]  # (T,C)
        T = x.shape[0]
        total_count = float(item["count"])
        meta = item["meta"]

        total_dur = max(T / float(fs), 1e-6)
        rate_trial = total_count / total_dur  # reps/s

        if T < win_len:
            win_dur = T / float(fs)
            windows.append({
                "data": x,
                "count": rate_trial * win_dur,
                "meta": f"{meta}__win[0:{T}]",
            })
            continue

        last_start = T - win_len
        starts = list(range(0, last_start + 1, stride))

        for st in starts:
            ed = st + win_len
            win_dur = win_len / float(fs)
            windows.append({
                "data": x[st:ed],
                "count": rate_trial * win_dur,
                "meta": f"{meta}__win[{st}:{ed}]",
            })

        if not drop_last:
            last_st = starts[-1] + stride
            if last_st < T:
                ed = T
                win_dur = (ed - last_st) / float(fs)
                windows.append({
                    "data": x[last_st:ed],
                    "count": rate_trial * win_dur,
                    "meta": f"{meta}__win[{last_st}:{ed}]",
                })

    return windows


# ---------------------------------------------------------------------
# 2.8) Dataset / Collate (same as your baseline)
# ---------------------------------------------------------------------
class TrialDataset(Dataset):
    def __init__(self, trial_list):
        self.trials = trial_list

    def __len__(self):
        return len(self.trials)

    def __getitem__(self, idx):
        item = self.trials[idx]
        data = torch.tensor(item['data'], dtype=torch.float32).transpose(0, 1)  # (C,T)
        count = torch.tensor(item['count'], dtype=torch.float32)
        return data, count, item['meta']


def collate_variable_length(batch):
    max_len = max([x[0].shape[1] for x in batch])
    C = batch[0][0].shape[0]

    padded_data, masks, counts, metas, lengths = [], [], [], [], []
    for data, count, meta in batch:
        T = data.shape[1]
        lengths.append(T)

        pad_size = max_len - T
        if pad_size > 0:
            pad = torch.zeros(C, pad_size)
            d_padded = torch.cat([data, pad], dim=1)
            mask = torch.cat([torch.ones(T), torch.zeros(pad_size)], dim=0)
        else:
            d_padded = data
            mask = torch.ones(T)

        padded_data.append(d_padded)
        masks.append(mask)
        counts.append(count)
        metas.append(meta)

    return {
        "data": torch.stack(padded_data),         # (B,C,Tmax)
        "mask": torch.stack(masks),               # (B,Tmax)
        "count": torch.stack(counts),             # (B,)
        "length": torch.tensor(lengths, dtype=torch.float32),  # (B,)
        "meta": metas
    }


# ---------------------------------------------------------------------
# Step counting helpers
# ---------------------------------------------------------------------
def make_loader_and_count_steps(train_data, batch_size, seed=42):
    g = torch.Generator()
    g.manual_seed(seed)
    loader = DataLoader(
        TrialDataset(train_data),
        batch_size=batch_size,
        shuffle=True,
        collate_fn=collate_variable_length,
        generator=g,
        num_workers=0
    )
    steps_per_epoch = len(loader)          # = ceil(N_samples / batch_size)
    n_samples = len(train_data)
    return n_samples, steps_per_epoch


def summarize_steps(steps_list):
    arr = np.array(steps_list, dtype=np.float32)
    return dict(min=int(arr.min()), mean=float(arr.mean()), max=int(arr.max()), std=float(arr.std()))


# ---------------------------------------------------------------------
# Main
# ---------------------------------------------------------------------
def main():
    CONFIG = {
        "seed": 42,
        "data_dir": "/content/drive/MyDrive/Colab Notebooks/HAR_data/MHEALTHDATASET",

        "COLUMN_NAMES": [
            'acc_chest_x', 'acc_chest_y', 'acc_chest_z',
            'ecg_1', 'ecg_2',
            'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
            'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
            'mag_ankle_x', 'mag_ankle_y', 'mag_ankle_z',
            'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
            'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z',
            'mag_arm_x', 'mag_arm_y', 'mag_arm_z',
            'activity_id'
        ],

        "TARGET_ACTIVITIES_MAP": {
            6:  'Waist bends forward',
            7:  'Frontal elevation of arms',
            8:  'Knees bending',
            10:  'Jogging',
            11: 'Running',
            12: 'Jump front & back',
        },

        "ACT_FEATURE_MAP": {
            6:  ['acc_chest_x','acc_chest_y','acc_chest_z','acc_ankle_x','acc_ankle_y','acc_ankle_z',
                 'gyro_ankle_x','gyro_ankle_y','gyro_ankle_z','acc_arm_x','acc_arm_y','acc_arm_z',
                 'gyro_arm_x','gyro_arm_y','gyro_arm_z'],
            7:  ['acc_chest_x','acc_chest_y','acc_chest_z','acc_ankle_x','acc_ankle_y','acc_ankle_z',
                 'gyro_ankle_x','gyro_ankle_y','gyro_ankle_z','acc_arm_x','acc_arm_y','acc_arm_z',
                 'gyro_arm_x','gyro_arm_y','gyro_arm_z'],
            8:  ['acc_chest_x','acc_chest_y','acc_chest_z','acc_ankle_x','acc_ankle_y','acc_ankle_z',
                 'gyro_ankle_x','gyro_ankle_y','gyro_ankle_z','acc_arm_x','acc_arm_y','acc_arm_z',
                 'gyro_arm_x','gyro_arm_y','gyro_arm_z'],
            10:  ['acc_chest_x','acc_chest_y','acc_chest_z','acc_ankle_x','acc_ankle_y','acc_ankle_z',
                 'gyro_ankle_x','gyro_ankle_y','gyro_ankle_z','acc_arm_x','acc_arm_y','acc_arm_z',
                 'gyro_arm_x','gyro_arm_y','gyro_arm_z'],
            11: ['acc_chest_x','acc_chest_y','acc_chest_z','acc_ankle_x','acc_ankle_y','acc_ankle_z',
                 'gyro_ankle_x','gyro_ankle_y','gyro_ankle_z','acc_arm_x','acc_arm_y','acc_arm_z',
                 'gyro_arm_x','gyro_arm_y','gyro_arm_z'],
            12: ['acc_chest_x','acc_chest_y','acc_chest_z','acc_ankle_x','acc_ankle_y','acc_ankle_z',
                 'gyro_ankle_x','gyro_ankle_y','gyro_ankle_z','acc_arm_x','acc_arm_y','acc_arm_z',
                 'gyro_arm_x','gyro_arm_y','gyro_arm_z'],
        },
        # Baseline training params (what you called "original")
        "epochs": 100,
        "batch_size": 64,
        "fs": 50,

        # window params (ours)
        "win_sec": 8.0,
        "stride_sec": 4.0,
        "drop_last": True,

        # Compare against your fixed budget
        "fixed_updates": 4000,
    }

    set_strict_seed(CONFIG["seed"])

    full_data = load_mhealth_dataset(
        CONFIG["data_dir"],
        CONFIG["TARGET_ACTIVITIES_MAP"],
        CONFIG["COLUMN_NAMES"]
    )
    if not full_data:
        return

    subjects = [f"subject{i}" for i in range(1, 11)]

    # ---- labels per activity ----
    ALL_LABELS_BY_ACT = {
        6: [
            ("subject1", 6, 21), ("subject2", 6, 19), ("subject3", 6, 21), ("subject4", 6, 20), ("subject5", 6, 20),
            ("subject6", 6, 20), ("subject7", 6, 20), ("subject8", 6, 21), ("subject9", 6, 21), ("subject10", 6, 20),
        ],
        7: [
            ("subject1", 7, 20), ("subject2", 7, 20), ("subject3", 7, 20), ("subject4", 7, 20), ("subject5", 7, 20),
            ("subject6", 7, 20), ("subject7", 7, 20), ("subject8", 7, 19), ("subject9", 7, 19), ("subject10", 7, 20),
        ],
        8: [
            ("subject1", 8, 20), ("subject2", 8, 21), ("subject3", 8, 21), ("subject4", 8, 19), ("subject5", 8, 20),
            ("subject6", 8, 20), ("subject7", 8, 21), ("subject8", 8, 21), ("subject9", 8, 21), ("subject10", 8, 21),
        ],
        10: [
            ("subject1", 10, 157), ("subject2", 10, 161), ("subject3", 10, 154), ("subject4", 10, 154), ("subject5", 10, 160),
            ("subject6", 10, 156), ("subject7", 10, 153), ("subject8", 10, 160), ("subject9", 10, 166), ("subject10", 10, 156),
        ],
        11: [
            ("subject1", 11, 165), ("subject2", 11, 158), ("subject3", 11, 174), ("subject4", 11, 163), ("subject5", 11, 157),
            ("subject6", 11, 172), ("subject7", 11, 149), ("subject8", 11, 166), ("subject9", 11, 174), ("subject10", 11, 172),
        ],
        12: [
            ("subject1", 12, 20), ("subject2", 12, 22), ("subject3", 12, 21), ("subject4", 12, 21), ("subject5", 12, 20),
            ("subject6", 12, 21), ("subject7", 12, 19), ("subject8", 12, 20), ("subject9", 12, 20), ("subject10", 12, 20),
        ]
    }

    print("\n" + "=" * 110)
    print("STEP COUNT REPORT (epoch-based baseline)  |  steps = optimizer.step() calls")
    print(f"epochs={CONFIG['epochs']} | batch_size={CONFIG['batch_size']} | fixed_updates={CONFIG['fixed_updates']}")
    print("=" * 110)

    for act_id, label_list in ALL_LABELS_BY_ACT.items():
        act_name = CONFIG["TARGET_ACTIVITIES_MAP"].get(act_id, str(act_id))
        print("\n" + "-" * 110)
        print(f"[Activity {act_id}] {act_name}")
        print("-" * 110)

        trial_steps_per_epoch = []
        ours_steps_per_epoch = []
        trial_total_steps = []
        ours_total_steps = []

        for fold_idx, test_subj in enumerate(subjects, start=1):
            train_labels = [x for x in label_list if x[0] != test_subj]
            test_labels  = [x for x in label_list if x[0] == test_subj]
            if len(test_labels) == 0:
                print(f"[Fold {fold_idx:2d}] skip (no test label for {test_subj})")
                continue

            train_trials = prepare_trial_list(
                train_labels, full_data,
                CONFIG["TARGET_ACTIVITIES_MAP"],
                CONFIG["ACT_FEATURE_MAP"]
            )

            # ------------------------
            # (A) trial_only: train_data = train_trials
            # ------------------------
            train_data_trial = train_trials
            n_trial, steps_ep_trial = make_loader_and_count_steps(
                train_data_trial, batch_size=CONFIG["batch_size"], seed=CONFIG["seed"]
            )
            total_steps_trial = CONFIG["epochs"] * steps_ep_trial
            eq_epochs_trial = CONFIG["fixed_updates"] / max(steps_ep_trial, 1)

            # ------------------------
            # (B) ours_window_proxy: train_data = windows
            # ------------------------
            train_data_ours = trial_list_to_windows(
                train_trials,
                fs=CONFIG["fs"],
                win_sec=CONFIG["win_sec"],
                stride_sec=CONFIG["stride_sec"],
                drop_last=CONFIG["drop_last"]
            )
            n_ours, steps_ep_ours = make_loader_and_count_steps(
                train_data_ours, batch_size=CONFIG["batch_size"], seed=CONFIG["seed"]
            )
            total_steps_ours = CONFIG["epochs"] * steps_ep_ours
            eq_epochs_ours = CONFIG["fixed_updates"] / max(steps_ep_ours, 1)

            trial_steps_per_epoch.append(steps_ep_trial)
            ours_steps_per_epoch.append(steps_ep_ours)
            trial_total_steps.append(total_steps_trial)
            ours_total_steps.append(total_steps_ours)

            print(
                f"[Fold {fold_idx:2d} | Test={test_subj}] "
                f"trial_only: N={n_trial:4d} steps/ep={steps_ep_trial:4d} total(100ep)={total_steps_trial:6d} "
                f"| fixed4000 ~= {eq_epochs_trial:6.2f} ep"
            )
            print(
                f"                     "
                f"ours_win : N={n_ours:4d} steps/ep={steps_ep_ours:4d} total(100ep)={total_steps_ours:6d} "
                f"| fixed4000 ~= {eq_epochs_ours:6.2f} ep"
            )

        # summary
        if len(trial_total_steps) > 0:
            s1 = summarize_steps(trial_total_steps)
            s2 = summarize_steps(ours_total_steps)
            print("\n[Summary: total steps for epochs=100]")
            print(f"  trial_only      : min={s1['min']} | mean={s1['mean']:.1f} | max={s1['max']} | std={s1['std']:.1f}")
            print(f"  ours_windowproxy: min={s2['min']} | mean={s2['mean']:.1f} | max={s2['max']} | std={s2['std']:.1f}")

            sp1 = summarize_steps(trial_steps_per_epoch)
            sp2 = summarize_steps(ours_steps_per_epoch)
            print("[Summary: steps per epoch]")
            print(f"  trial_only      : min={sp1['min']} | mean={sp1['mean']:.2f} | max={sp1['max']} | std={sp1['std']:.2f}")
            print(f"  ours_windowproxy: min={sp2['min']} | mean={sp2['mean']:.2f} | max={sp2['max']} | std={sp2['std']:.2f}")

    print("\nDONE.")


if __name__ == "__main__":
    main()
# Out:
# Loading 10 subjects from /content/drive/MyDrive/Colab Notebooks/HAR_data/MHEALTHDATASET...
#
# ==============================================================================================================
# STEP COUNT REPORT (epoch-based baseline)  |  steps = optimizer.step() calls
# epochs=100 | batch_size=64 | fixed_updates=4000
# ==============================================================================================================
#
# --------------------------------------------------------------------------------------------------------------
# [Activity 6] Waist bends forward
# --------------------------------------------------------------------------------------------------------------
# [Fold  1 | Test=subject1] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 113 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  2 | Test=subject2] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 113 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  3 | Test=subject3] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 112 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  4 | Test=subject4] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 112 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  5 | Test=subject5] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 115 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  6 | Test=subject6] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 117 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  7 | Test=subject7] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 113 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  8 | Test=subject8] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 118 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  9 | Test=subject9] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 114 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold 10 | Test=subject10] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 116 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
#
# [Summary: total steps for epochs=100]
#   trial_only      : min=100 | mean=100.0 | max=100 | std=0.0
#   ours_windowproxy: min=200 | mean=200.0 | max=200 | std=0.0
# [Summary: steps per epoch]
#   trial_only      : min=1 | mean=1.00 | max=1 | std=0.00
#   ours_windowproxy: min=2 | mean=2.00 | max=2 | std=0.00
#
# --------------------------------------------------------------------------------------------------------------
# [Activity 7] Frontal elevation of arms
# --------------------------------------------------------------------------------------------------------------
# [Fold  1 | Test=subject1] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 118 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  2 | Test=subject2] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 117 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  3 | Test=subject3] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 117 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  4 | Test=subject4] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 117 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  5 | Test=subject5] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 119 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  6 | Test=subject6] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 123 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  7 | Test=subject7] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 120 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  8 | Test=subject8] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 118 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  9 | Test=subject9] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 119 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold 10 | Test=subject10] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 120 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
#
# [Summary: total steps for epochs=100]
#   trial_only      : min=100 | mean=100.0 | max=100 | std=0.0
#   ours_windowproxy: min=200 | mean=200.0 | max=200 | std=0.0
# [Summary: steps per epoch]
#   trial_only      : min=1 | mean=1.00 | max=1 | std=0.00
#   ours_windowproxy: min=2 | mean=2.00 | max=2 | std=0.00
#
# --------------------------------------------------------------------------------------------------------------
# [Activity 8] Knees bending
# --------------------------------------------------------------------------------------------------------------
# [Fold  1 | Test=subject1] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 116 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  2 | Test=subject2] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 115 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  3 | Test=subject3] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 117 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  4 | Test=subject4] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 117 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  5 | Test=subject5] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 119 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  6 | Test=subject6] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 121 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  7 | Test=subject7] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 118 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  8 | Test=subject8] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 120 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  9 | Test=subject9] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 118 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold 10 | Test=subject10] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 118 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
#
# [Summary: total steps for epochs=100]
#   trial_only      : min=100 | mean=100.0 | max=100 | std=0.0
#   ours_windowproxy: min=200 | mean=200.0 | max=200 | std=0.0
# [Summary: steps per epoch]
#   trial_only      : min=1 | mean=1.00 | max=1 | std=0.00
#   ours_windowproxy: min=2 | mean=2.00 | max=2 | std=0.00
#
# --------------------------------------------------------------------------------------------------------------
# [Activity 10] Jogging
# --------------------------------------------------------------------------------------------------------------
# [Fold  1 | Test=subject1] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  2 | Test=subject2] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  3 | Test=subject3] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  4 | Test=subject4] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  5 | Test=subject5] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  6 | Test=subject6] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  7 | Test=subject7] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  8 | Test=subject8] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  9 | Test=subject9] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold 10 | Test=subject10] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
#
# [Summary: total steps for epochs=100]
#   trial_only      : min=100 | mean=100.0 | max=100 | std=0.0
#   ours_windowproxy: min=200 | mean=200.0 | max=200 | std=0.0
# [Summary: steps per epoch]
#   trial_only      : min=1 | mean=1.00 | max=1 | std=0.00
#   ours_windowproxy: min=2 | mean=2.00 | max=2 | std=0.00
#
# --------------------------------------------------------------------------------------------------------------
# [Activity 11] Running
# --------------------------------------------------------------------------------------------------------------
# [Fold  1 | Test=subject1] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  2 | Test=subject2] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  3 | Test=subject3] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  4 | Test=subject4] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  5 | Test=subject5] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  6 | Test=subject6] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  7 | Test=subject7] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  8 | Test=subject8] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold  9 | Test=subject9] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
# [Fold 10 | Test=subject10] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N= 126 steps/ep=   2 total(100ep)=   200 | fixed4000 ~= 2000.00 ep
#
# [Summary: total steps for epochs=100]
#   trial_only      : min=100 | mean=100.0 | max=100 | std=0.0
#   ours_windowproxy: min=200 | mean=200.0 | max=200 | std=0.0
# [Summary: steps per epoch]
#   trial_only      : min=1 | mean=1.00 | max=1 | std=0.00
#   ours_windowproxy: min=2 | mean=2.00 | max=2 | std=0.00
#
# --------------------------------------------------------------------------------------------------------------
# [Activity 12] Jump front & back
# --------------------------------------------------------------------------------------------------------------
# [Fold  1 | Test=subject1] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N=  36 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
# [Fold  2 | Test=subject2] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N=  36 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
# [Fold  3 | Test=subject3] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N=  36 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
# [Fold  4 | Test=subject4] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N=  36 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
# [Fold  5 | Test=subject5] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N=  36 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
# [Fold  6 | Test=subject6] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N=  36 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
# [Fold  7 | Test=subject7] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N=  36 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
# [Fold  8 | Test=subject8] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N=  36 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
# [Fold  9 | Test=subject9] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N=  36 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
# [Fold 10 | Test=subject10] trial_only: N=   9 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#                      ours_win : N=  36 steps/ep=   1 total(100ep)=   100 | fixed4000 ~= 4000.00 ep
#
# [Summary: total steps for epochs=100]
#   trial_only      : min=100 | mean=100.0 | max=100 | std=0.0
#   ours_windowproxy: min=100 | mean=100.0 | max=100 | std=0.0
# [Summary: steps per epoch]
#   trial_only      : min=1 | mean=1.00 | max=1 | std=0.00
#   ours_windowproxy: min=1 | mean=1.00 | max=1 | std=0.00
#
# DONE.

# %%
# ============================================================
# Effect of Windowing Experiment (mHealth) — FULL CODE
#
# What you get:
# 1) Trial-only (TRAIN: full-trial samples)  VS.  Ours (TRAIN: window-proxy supervision)
# 2) Train step matching: BOTH variants train for the SAME number of optimizer updates (MAX_UPDATES)
# 3) Metrics: MAE, MAPE, STD (std across LOSO folds) — per activity & per variant
# 4) Run LOSO for multiple activities (e.g., 6 activities). You fill GT counts per activity.
#
# Notes:
# - TEST inference is unified: windowing inference (same for both variants) -> fair comparison.
# - You can optionally add multiple seeds via CONFIG["seeds"] (kept simple by default).
# ============================================================

import os
import glob
import random
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from scipy.ndimage import gaussian_filter1d

# ---------------------------------------------------------------------
# 1) Strict Seeding
# ---------------------------------------------------------------------
def set_strict_seed(seed: int):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


# ---------------------------------------------------------------------
# 2) Data Loading
# ---------------------------------------------------------------------
def load_mhealth_dataset(data_dir, target_activities_map, column_names):
    full_dataset = {}
    file_list = sorted(glob.glob(os.path.join(data_dir, "mHealth_subject*.log")))

    if not file_list:
        print(f"[Warning] No mHealth logs found in {data_dir}")
        return {}

    print(f"Loading {len(file_list)} subjects from {data_dir}...")

    for file_path in file_list:
        file_name = os.path.basename(file_path)
        subj_part = file_name.split('.')[0]
        try:
            subj_id_num = int(''.join(filter(str.isdigit, subj_part)))
            subj_key = f"subject{subj_id_num}"
        except:
            subj_key = subj_part

        try:
            df = pd.read_csv(file_path, sep="\t", header=None)
            df = df.iloc[:, :len(column_names)]
            df.columns = column_names

            subj_data = {}
            for label_code, activity_name in target_activities_map.items():
                activity_df = df[df['activity_id'] == label_code].copy()
                if not activity_df.empty:
                    subj_data[activity_name] = activity_df.drop(columns=['activity_id'])

            full_dataset[subj_key] = subj_data
        except Exception as e:
            print(f"Error loading {file_name}: {e}")
            pass

    return full_dataset


def prepare_trial_list(label_config, full_data, target_map, feature_map):
    """
    label_config: list of (subj, act_id, gt_count)
    returns: list of dicts {data:(T,C), count:float, meta:str}
    """
    trial_list = []
    for subj, act_id, gt_count in label_config:
        act_name = target_map.get(act_id)
        feats = feature_map.get(act_id)

        if act_name is None or feats is None:
            print(f"[Skip] Missing mapping for act_id={act_id}")
            continue

        if subj in full_data and act_name in full_data[subj]:
            raw_df = full_data[subj][act_name][feats]
            raw_np = raw_df.values.astype(np.float32)

            # Z-score normalization per trial
            mean = raw_np.mean(axis=0)
            std = raw_np.std(axis=0) + 1e-6
            norm_np = (raw_np - mean) / std

            trial_list.append({
                'data': norm_np,              # (T, C)
                'count': float(gt_count),      # trial total count
                'meta': f"{subj}_{act_name}"
            })
        else:
            print(f"[Skip] Missing data for {subj} - {act_name}")

    return trial_list


# ---------------------------------------------------------------------
# 2.5) Windowing (TRAIN only for Ours)
# ---------------------------------------------------------------------
def trial_list_to_windows(trial_list, fs, win_sec=8.0, stride_sec=4.0, drop_last=True):
    """
    TRAIN-only expansion: trial -> sliding windows
    window proxy label:
      rate_trial = count_total / total_duration
      count_window = rate_trial * window_duration
    """
    win_len = int(round(win_sec * fs))
    stride = int(round(stride_sec * fs))
    assert win_len > 0 and stride > 0

    windows = []
    for item in trial_list:
        x = item["data"]  # (T,C)
        T = x.shape[0]
        total_count = float(item["count"])
        meta = item["meta"]

        total_dur = max(T / float(fs), 1e-6)
        rate_trial = total_count / total_dur  # reps/s

        if T < win_len:
            win_dur = T / float(fs)
            windows.append({
                "data": x,
                "count": rate_trial * win_dur,
                "meta": f"{meta}__win[0:{T}]",
                "parent_meta": meta,
                "parent_T": T,
                "win_start": 0,
                "win_end": T,
            })
            continue

        last_start = T - win_len
        starts = list(range(0, last_start + 1, stride))

        for st in starts:
            ed = st + win_len
            win_dur = win_len / float(fs)
            windows.append({
                "data": x[st:ed],
                "count": rate_trial * win_dur,
                "meta": f"{meta}__win[{st}:{ed}]",
                "parent_meta": meta,
                "parent_T": T,
                "win_start": st,
                "win_end": ed,
            })

        if not drop_last:
            last_st = starts[-1] + stride
            if last_st < T:
                ed = T
                win_dur = (ed - last_st) / float(fs)
                windows.append({
                    "data": x[last_st:ed],
                    "count": rate_trial * win_dur,
                    "meta": f"{meta}__win[{last_st}:{ed}]",
                    "parent_meta": meta,
                    "parent_T": T,
                    "win_start": last_st,
                    "win_end": ed,
                })

    return windows


def predict_count_by_windowing(model, x_np, fs, win_sec, stride_sec, device, tau=1.0, batch_size=64):
    """
    TEST: trial -> sliding windows inference -> window rate 평균 -> total count
    x_np: (T,C) numpy (already normalized)
    return: pred_count(float), window_rates(np.ndarray)
    """
    win_len = int(round(win_sec * fs))
    stride = int(round(stride_sec * fs))
    T = x_np.shape[0]
    total_dur = T / float(fs)

    # short trial -> 1 forward
    if T <= win_len:
        x_tensor = torch.tensor(x_np, dtype=torch.float32).transpose(0, 1).unsqueeze(0).to(device)  # (1,C,T)
        with torch.no_grad():
            rate_hat, _, _, _ = model(x_tensor, mask=None, tau=tau)
        pred_count = float(rate_hat.item() * total_dur)
        return pred_count, np.array([float(rate_hat.item())], dtype=np.float32)

    starts = list(range(0, T - win_len + 1, stride))
    windows = np.stack([x_np[st:st + win_len] for st in starts], axis=0)  # (N, win_len, C)

    xw = torch.tensor(windows, dtype=torch.float32).permute(0, 2, 1).to(device)  # (N, C, win_len)

    rates = []
    model.eval()
    with torch.no_grad():
        for i in range(0, xw.shape[0], batch_size):
            xb = xw[i:i + batch_size]
            r_hat, _, _, _ = model(xb, mask=None, tau=tau)  # (B,)
            rates.append(r_hat.detach().cpu().numpy())

    rates = np.concatenate(rates, axis=0)  # (N,)
    rate_mean = float(rates.mean())
    pred_count = rate_mean * total_dur
    return float(pred_count), rates


# ---------------------------------------------------------------------
# 2.8) Dataset / Collate
# ---------------------------------------------------------------------
class TrialDataset(Dataset):
    def __init__(self, trial_list):
        self.trials = trial_list

    def __len__(self):
        return len(self.trials)

    def __getitem__(self, idx):
        item = self.trials[idx]
        data = torch.tensor(item['data'], dtype=torch.float32).transpose(0, 1)  # (C, T)
        count = torch.tensor(item['count'], dtype=torch.float32)
        return data, count, item['meta']


def collate_variable_length(batch):
    max_len = max([x[0].shape[1] for x in batch])
    C = batch[0][0].shape[0]

    padded_data, masks, counts, metas, lengths = [], [], [], [], []
    for data, count, meta in batch:
        T = data.shape[1]
        lengths.append(T)

        pad_size = max_len - T
        if pad_size > 0:
            pad = torch.zeros(C, pad_size)
            d_padded = torch.cat([data, pad], dim=1)
            mask = torch.cat([torch.ones(T), torch.zeros(pad_size)], dim=0)
        else:
            d_padded = data
            mask = torch.ones(T)

        padded_data.append(d_padded)
        masks.append(mask)
        counts.append(count)
        metas.append(meta)

    return {
        "data": torch.stack(padded_data),         # (B, C, T_max)
        "mask": torch.stack(masks),               # (B, T_max)
        "count": torch.stack(counts),             # (B,)
        "length": torch.tensor(lengths, dtype=torch.float32),  # (B,)
        "meta": metas
    }


# ---------------------------------------------------------------------
# 3) Model
# ---------------------------------------------------------------------
class ManifoldEncoder(nn.Module):
    def __init__(self, input_ch, hidden_dim=128, latent_dim=16):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(input_ch, hidden_dim, 5, padding=2),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, hidden_dim, 5, padding=2),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, latent_dim, 1)
        )

    def forward(self, x):
        z = self.net(x)            # (B, D, T)
        z = z.transpose(1, 2)      # (B, T, D)
        return z


class ManifoldDecoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim, out_ch):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv1d(latent_dim, hidden_dim, 5, padding=2),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, hidden_dim, 5, padding=2),
            nn.ReLU(),
            nn.Conv1d(hidden_dim, out_ch, 1)
        )

    def forward(self, z):
        zt = z.transpose(1, 2)     # (B, D, T)
        x_hat = self.net(zt)       # (B, C, T)
        return x_hat


class MultiRateHead(nn.Module):
    def __init__(self, latent_dim=16, hidden=64, K_max=6):
        super().__init__()
        self.K_max = K_max
        self.net = nn.Sequential(
            nn.Linear(latent_dim, hidden),
            nn.ReLU(),
            nn.Linear(hidden, 1 + K_max)  # [amp_logit | phase_logits...]
        )

    def forward(self, z, tau=1.0):
        out = self.net(z)                               # (B,T,1+K)
        amp = F.softplus(out[..., 0])                   # (B,T) >=0
        phase_logits = out[..., 1:]                     # (B,T,K)
        phase = F.softmax(phase_logits / tau, dim=-1)   # (B,T,K)
        return amp, phase, phase_logits


class KAutoCountModel(nn.Module):
    """
    - micro_rate_t = amp(t)
    - phase_p(t,k) distributes micro-events across K streams
    - k_hat computed from p_bar (effective K)
    - rep_rate_t = micro_rate_t / k_hat
    - output avg_rep_rate over valid time
    """
    def __init__(self, input_ch, hidden_dim=128, latent_dim=16, K_max=6):
        super().__init__()
        self.encoder = ManifoldEncoder(input_ch, hidden_dim, latent_dim)
        self.decoder = ManifoldDecoder(latent_dim, hidden_dim, input_ch)
        self.rate_head = MultiRateHead(latent_dim, hidden=hidden_dim, K_max=K_max)
        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, (nn.Conv1d, nn.Linear)):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
        with torch.no_grad():
            b = self.rate_head.net[-1].bias
            b.zero_()
            b[0].fill_(-2.0)  # amp bias only

    @staticmethod
    def _masked_mean_time(x, mask=None, eps=1e-6):
        if mask is None:
            return x.mean(dim=1)
        if x.dim() == 2:
            m = mask.to(dtype=x.dtype, device=x.device)
            return (x * m).sum(dim=1) / (m.sum(dim=1) + eps)
        elif x.dim() == 3:
            m = mask.to(dtype=x.dtype, device=x.device).unsqueeze(-1)
            return (x * m).sum(dim=1) / (m.sum(dim=1) + eps)
        else:
            raise ValueError(f"Unsupported dim for masked mean: {x.dim()}")

    def forward(self, x, mask=None, tau=1.0):
        z = self.encoder(x)              # (B,T,D)
        x_hat = self.decoder(z)          # (B,C,T)

        amp_t, phase_p, phase_logits = self.rate_head(z, tau=tau)  # amp:(B,T), phase:(B,T,K)
        rates_k_t = amp_t.unsqueeze(-1) * phase_p                   # (B,T,K)

        micro_rate_t = amp_t                                        # (B,T)

        p_bar = self._masked_mean_time(phase_p, mask)               # (B,K)
        k_hat = 1.0 / (p_bar.pow(2).sum(dim=1) + 1e-6)              # (B,) ~ [1,K]

        rep_rate_t = micro_rate_t / (k_hat.unsqueeze(1) + 1e-6)     # (B,T)
        if mask is not None:
            rep_rate_t = rep_rate_t * mask

        if mask is None:
            avg_rep_rate = rep_rate_t.mean(dim=1)
        else:
            avg_rep_rate = (rep_rate_t * mask).sum(dim=1) / (mask.sum(dim=1) + 1e-6)

        aux = {
            "rates_k_t": rates_k_t,
            "phase_p": phase_p,
            "phase_logits": phase_logits,
            "micro_rate_t": micro_rate_t,
            "rep_rate_t": rep_rate_t,
            "k_hat": k_hat,
        }
        return avg_rep_rate, z, x_hat, aux


# ---------------------------------------------------------------------
# 4) Loss utils
# ---------------------------------------------------------------------
def masked_recon_mse(x_hat, x, mask, eps=1e-6):
    mask = mask.to(dtype=x.dtype, device=x.device)
    mask_bc = mask.unsqueeze(1)              # (B,1,T)
    se = (x_hat - x) ** 2                    # (B,C,T)
    se = se * mask_bc
    denom = (mask.sum() * x.shape[1]) + eps  # valid(B*T)*C
    return se.sum() / denom


def temporal_smoothness(v, mask=None, eps=1e-6):
    dv = torch.abs(v[:, 1:] - v[:, :-1])  # (B,T-1)
    if mask is None:
        return dv.mean()
    m = mask[:, 1:] * mask[:, :-1]
    m = m.to(dtype=dv.dtype, device=dv.device)
    return (dv * m).sum() / (m.sum() + eps)


def phase_entropy_loss(phase_p, mask=None, eps=1e-8):
    ent = -(phase_p * (phase_p + eps).log()).sum(dim=-1)  # (B,T)
    if mask is None:
        return ent.mean()
    ent = ent * mask
    return ent.sum() / (mask.sum() + eps)


def effK_usage_loss(phase_p, mask=None, eps=1e-6):
    if mask is None:
        p_bar = phase_p.mean(dim=1)  # (B,K)
    else:
        m = mask.to(dtype=phase_p.dtype, device=phase_p.device).unsqueeze(-1)  # (B,T,1)
        p_bar = (phase_p * m).sum(dim=1) / (m.sum(dim=1) + eps)

    effK = 1.0 / (p_bar.pow(2).sum(dim=1) + eps)
    return effK.mean(), effK.detach()


# ---------------------------------------------------------------------
# 5) Train by FIXED UPDATES (step matching)
# ---------------------------------------------------------------------
def train_one_step(model, batch, optimizer, config, device):
    model.train()

    fs = config["fs"]
    tau = config.get("tau", 1.0)

    lam_recon = config.get("lambda_recon", 1.0)
    lam_smooth = config.get("lambda_smooth", 0.05)
    lam_phase_ent = config.get("lambda_phase_ent", 0.01)
    lam_effk = config.get("lambda_effk", 0.005)

    x = batch["data"].to(device)         # (B,C,T)
    mask = batch["mask"].to(device)      # (B,T)
    y_count = batch["count"].to(device)  # (B,)
    length = batch["length"].to(device)  # (B,)

    duration = torch.clamp(length / fs, min=1e-6)  # sec
    y_rate = y_count / duration                    # reps/s

    optimizer.zero_grad(set_to_none=True)

    rate_hat, z, x_hat, aux = model(x, mask, tau=tau)

    loss_rate = F.mse_loss(rate_hat, y_rate)
    loss_recon = masked_recon_mse(x_hat, x, mask)
    loss_smooth = temporal_smoothness(aux["rep_rate_t"], mask)
    loss_phase_ent = phase_entropy_loss(aux["phase_p"], mask)
    loss_effk, _ = effK_usage_loss(aux["phase_p"], mask)

    loss = (loss_rate
            + lam_recon * loss_recon
            + lam_smooth * loss_smooth
            + lam_phase_ent * loss_phase_ent
            + lam_effk * loss_effk)

    loss.backward()
    optimizer.step()

    with torch.no_grad():
        count_hat = rate_hat * duration
        mae_count = torch.abs(count_hat - y_count).mean().item()

    stats = {
        "loss": float(loss.item()),
        "loss_rate": float(loss_rate.item()),
        "loss_recon": float(loss_recon.item()),
        "loss_smooth": float(loss_smooth.item()),
        "loss_phase_ent": float(loss_phase_ent.item()),
        "loss_effk": float(loss_effk.item()),
        "mae_count": float(mae_count),
    }
    return stats


def train_by_updates(model, loader, optimizer, scheduler, config, device, max_updates=3000, log_every=500):
    """
    핵심: optimizer.update 횟수(=step)를 정확히 max_updates로 고정
    -> Trial-only vs Window-proxy 공정 비교
    """
    it = iter(loader)
    agg = {k: 0.0 for k in ["loss", "loss_rate", "loss_recon", "loss_smooth", "loss_phase_ent", "loss_effk", "mae_count"]}

    for step in range(1, max_updates + 1):
        try:
            batch = next(it)
        except StopIteration:
            it = iter(loader)
            batch = next(it)

        st = train_one_step(model, batch, optimizer, config, device)
        for k in agg:
            agg[k] += st[k]

        if scheduler is not None:
            scheduler.step()

        if (log_every is not None) and (step % log_every == 0):
            avg = {k: agg[k] / step for k in agg}
            print(f"  [train] step {step:5d}/{max_updates} | loss={avg['loss']:.4f} | mae={avg['mae_count']:.3f}")

    avg = {k: agg[k] / max_updates for k in agg}
    return avg


# ---------------------------------------------------------------------
# 6) Eval (MAE / MAPE)
# ---------------------------------------------------------------------
def eval_on_trials_window_infer(model, test_trials, config, device):
    """
    Unified evaluation for BOTH variants:
    - Use windowing inference at test time
    - Return fold-avg MAE, MAPE
    """
    fs = config["fs"]
    win_sec = config["win_sec"]
    stride_sec = config["stride_sec"]
    tau = config.get("tau", 1.0)
    bs = config.get("batch_size", 64)

    mae_list = []
    mape_list = []

    model.eval()
    for item in test_trials:
        x_np = item["data"]
        gt = float(item["count"])

        pred, _ = predict_count_by_windowing(
            model,
            x_np=x_np,
            fs=fs,
            win_sec=win_sec,
            stride_sec=stride_sec,
            device=device,
            tau=tau,
            batch_size=bs
        )

        ae = abs(pred - gt)
        mae_list.append(ae)

        # MAPE (%)
        denom = max(abs(gt), 1e-6)
        mape_list.append((ae / denom) * 100.0)

    fold_mae = float(np.mean(mae_list)) if len(mae_list) > 0 else np.nan
    fold_mape = float(np.mean(mape_list)) if len(mape_list) > 0 else np.nan
    return fold_mae, fold_mape


# ---------------------------------------------------------------------
# 7) Main: multi-activity LOSO, two variants
# ---------------------------------------------------------------------
def main():
    CONFIG = {
        # Repro
        "seeds": [42],   # 필요하면 [1,2,3,4,5] 로 확장 가능

        # Data
        "data_dir": "/content/drive/MyDrive/Colab Notebooks/HAR_data/MHEALTHDATASET",
        "fs": 50,

        "COLUMN_NAMES": [
            'acc_chest_x', 'acc_chest_y', 'acc_chest_z',
            'ecg_1', 'ecg_2',
            'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
            'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
            'mag_ankle_x', 'mag_ankle_y', 'mag_ankle_z',
            'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
            'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z',
            'mag_arm_x', 'mag_arm_y', 'mag_arm_z',
            'activity_id'
        ],

        # ====== ✅ Put YOUR 6 activities here ======
        # act_id -> name
        "TARGET_ACTIVITIES_MAP": {
            6:  'Waist bends forward',
            7:  'Frontal elevation of arms',
            8:  'Knees bending',
            10:  'Jogging',
            11: 'Running',
            12: 'Jump front & back',
        },

        # act_id -> feature list (you can keep same list for all)
        "ACT_FEATURE_MAP": {
            6:  ['acc_chest_x','acc_chest_y','acc_chest_z','acc_ankle_x','acc_ankle_y','acc_ankle_z',
                 'gyro_ankle_x','gyro_ankle_y','gyro_ankle_z','acc_arm_x','acc_arm_y','acc_arm_z',
                 'gyro_arm_x','gyro_arm_y','gyro_arm_z'],
            7:  ['acc_chest_x','acc_chest_y','acc_chest_z','acc_ankle_x','acc_ankle_y','acc_ankle_z',
                 'gyro_ankle_x','gyro_ankle_y','gyro_ankle_z','acc_arm_x','acc_arm_y','acc_arm_z',
                 'gyro_arm_x','gyro_arm_y','gyro_arm_z'],
            8:  ['acc_chest_x','acc_chest_y','acc_chest_z','acc_ankle_x','acc_ankle_y','acc_ankle_z',
                 'gyro_ankle_x','gyro_ankle_y','gyro_ankle_z','acc_arm_x','acc_arm_y','acc_arm_z',
                 'gyro_arm_x','gyro_arm_y','gyro_arm_z'],
            10:  ['acc_chest_x','acc_chest_y','acc_chest_z','acc_ankle_x','acc_ankle_y','acc_ankle_z',
                 'gyro_ankle_x','gyro_ankle_y','gyro_ankle_z','acc_arm_x','acc_arm_y','acc_arm_z',
                 'gyro_arm_x','gyro_arm_y','gyro_arm_z'],
            11: ['acc_chest_x','acc_chest_y','acc_chest_z','acc_ankle_x','acc_ankle_y','acc_ankle_z',
                 'gyro_ankle_x','gyro_ankle_y','gyro_ankle_z','acc_arm_x','acc_arm_y','acc_arm_z',
                 'gyro_arm_x','gyro_arm_y','gyro_arm_z'],
            12: ['acc_chest_x','acc_chest_y','acc_chest_z','acc_ankle_x','acc_ankle_y','acc_ankle_z',
                 'gyro_ankle_x','gyro_ankle_y','gyro_ankle_z','acc_arm_x','acc_arm_y','acc_arm_z',
                 'gyro_arm_x','gyro_arm_y','gyro_arm_z'],
        },

        # Train (step matching 핵심)
        "batch_size": 64,
        "lr": 5e-4,
        "MAX_UPDATES": 200,  # ✅ Trial-only vs Ours 둘 다 정확히 이 step만큼 학습
        "log_every": 50,

        # Windowing (TRAIN for Ours, TEST for both)
        "win_sec": 8.0,
        "stride_sec": 4.0,
        "drop_last": True,

        # Model
        "hidden_dim": 128,
        "latent_dim": 16,
        "K_max": 6,

        # Loss weights
        "lambda_recon": 1.0,
        "lambda_smooth": 0.05,
        "lambda_phase_ent": 0.01,
        "lambda_effk": 0.0075,
        "tau": 1.0,

        # Variants
        "VARIANTS": ["trial_only", "ours_window_proxy"],

        # ====== ✅ YOU FILL THESE GT COUNTS ======
        # act_id -> list of (subjectX, act_id, gt_count)
        "GT_LABELS_BY_ACT": {
            6: [
                ("subject1", 6, 21), ("subject2", 6, 19), ("subject3", 6, 21), ("subject4", 6, 20), ("subject5", 6, 20),
                ("subject6", 6, 20), ("subject7", 6, 20), ("subject8", 6, 21), ("subject9", 6, 21), ("subject10", 6, 20),
            ],
            7: [
                ("subject1", 7, 20), ("subject2", 7, 20), ("subject3", 7, 20), ("subject4", 7, 20), ("subject5", 7, 20),
                ("subject6", 7, 20), ("subject7", 7, 20), ("subject8", 7, 19), ("subject9", 7, 19), ("subject10", 7, 20),
            ],
            8: [
                ("subject1", 8, 20), ("subject2", 8, 21), ("subject3", 8, 21), ("subject4", 8, 19), ("subject5", 8, 20),
                ("subject6", 8, 20), ("subject7", 8, 21), ("subject8", 8, 21), ("subject9", 8, 21), ("subject10", 8, 21),
            ],
            10: [
                ("subject1", 10, 157), ("subject2", 10, 161), ("subject3", 10, 154), ("subject4", 10, 154), ("subject5", 10, 160),
                ("subject6", 10, 156), ("subject7", 10, 153), ("subject8", 10, 160), ("subject9", 10, 166), ("subject10", 10, 156),
            ],
            11: [
                ("subject1", 11, 165), ("subject2", 11, 158), ("subject3", 11, 174), ("subject4", 11, 163), ("subject5", 11, 157),
                ("subject6", 11, 172), ("subject7", 11, 149), ("subject8", 11, 166), ("subject9", 11, 174), ("subject10", 11, 172),
            ],
            12: [
                ("subject1", 12, 20), ("subject2", 12, 22), ("subject3", 12, 21), ("subject4", 12, 21), ("subject5", 12, 20),
                ("subject6", 12, 21), ("subject7", 12, 19), ("subject8", 12, 20), ("subject9", 12, 20), ("subject10", 12, 20),
            ],
        },
    }

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Device: {device}")

    # Load once (contains only activities in TARGET_ACTIVITIES_MAP)
    full_data = load_mhealth_dataset(CONFIG["data_dir"], CONFIG["TARGET_ACTIVITIES_MAP"], CONFIG["COLUMN_NAMES"])
    if not full_data:
        return

    subjects = [f"subject{i}" for i in range(1, 11)]

    # Results container
    all_records = []

    # Run per seed (optional)
    for seed in CONFIG["seeds"]:
        print("\n" + "=" * 90)
        print(f"SEED = {seed}")
        print("=" * 90)
        set_strict_seed(seed)

        # Run per activity
        for act_id, act_name in CONFIG["TARGET_ACTIVITIES_MAP"].items():
            gt_labels = CONFIG["GT_LABELS_BY_ACT"].get(act_id, [])
            if gt_labels is None or len(gt_labels) == 0:
                print(f"\n[Skip Activity] act_id={act_id} ({act_name}) because GT_LABELS_BY_ACT is empty.")
                continue

            print("\n" + "-" * 90)
            print(f"ACTIVITY {act_id}: {act_name}")
            print("-" * 90)

            # Store fold metrics per variant
            fold_metrics = {v: {"mae": [], "mape": []} for v in CONFIG["VARIANTS"]}

            for fold_idx, test_subj in enumerate(subjects):
                set_strict_seed(seed)

                # Split labels
                train_labels = [x for x in gt_labels if x[0] != test_subj]
                test_labels  = [x for x in gt_labels if x[0] == test_subj]

                # Prepare trials
                train_trials = prepare_trial_list(train_labels, full_data, CONFIG["TARGET_ACTIVITIES_MAP"], CONFIG["ACT_FEATURE_MAP"])
                test_trials  = prepare_trial_list(test_labels,  full_data, CONFIG["TARGET_ACTIVITIES_MAP"], CONFIG["ACT_FEATURE_MAP"])

                if len(test_trials) == 0:
                    print(f"[Skip Fold] act={act_id} Fold {fold_idx+1}: {test_subj} has no data.")
                    continue
                if len(train_trials) == 0:
                    print(f"[Skip Fold] act={act_id} Fold {fold_idx+1}: train_trials empty.")
                    continue

                # For each variant: train -> eval
                for variant in CONFIG["VARIANTS"]:
                    # Build train samples
                    if variant == "trial_only":
                        train_samples = train_trials
                    elif variant == "ours_window_proxy":
                        train_samples = trial_list_to_windows(
                            train_trials,
                            fs=CONFIG["fs"],
                            win_sec=CONFIG["win_sec"],
                            stride_sec=CONFIG["stride_sec"],
                            drop_last=CONFIG["drop_last"],
                        )
                    else:
                        raise ValueError(f"Unknown variant: {variant}")

                    # Dataloader
                    g = torch.Generator()
                    g.manual_seed(seed)

                    train_loader = DataLoader(
                        TrialDataset(train_samples),
                        batch_size=CONFIG["batch_size"],
                        shuffle=True,
                        collate_fn=collate_variable_length,
                        generator=g,
                        num_workers=0,
                        drop_last=False,
                    )

                    # Model init
                    input_ch = train_samples[0]['data'].shape[1]
                    model = KAutoCountModel(
                        input_ch=input_ch,
                        hidden_dim=CONFIG["hidden_dim"],
                        latent_dim=CONFIG["latent_dim"],
                        K_max=CONFIG["K_max"],
                    ).to(device)

                    optimizer = torch.optim.Adam(model.parameters(), lr=CONFIG["lr"])

                    # Scheduler in "updates" domain (optional)
                    # Example: half LR every 2000 updates
                    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=max(1, CONFIG["MAX_UPDATES"] // 2), gamma=0.5)

                    print(f"\n[Fold {fold_idx+1:2d} | Test={test_subj} | {variant}] TRAIN (fixed updates={CONFIG['MAX_UPDATES']})")
                    _train_avg = train_by_updates(
                        model=model,
                        loader=train_loader,
                        optimizer=optimizer,
                        scheduler=scheduler,
                        config=CONFIG,
                        device=device,
                        max_updates=CONFIG["MAX_UPDATES"],
                        log_every=CONFIG.get("log_every", 800)
                    )

                    # Eval (windowing inference for BOTH variants)
                    fold_mae, fold_mape = eval_on_trials_window_infer(model, test_trials, CONFIG, device)

                    fold_metrics[variant]["mae"].append(fold_mae)
                    fold_metrics[variant]["mape"].append(fold_mape)

                    print(f"[Fold {fold_idx+1:2d} | {variant}]  MAE={fold_mae:.3f} | MAPE={fold_mape:.2f}%")

            # Summarize per activity
            for variant in CONFIG["VARIANTS"]:
                maes = np.array(fold_metrics[variant]["mae"], dtype=np.float32)
                mapes = np.array(fold_metrics[variant]["mape"], dtype=np.float32)

                rec = {
                    "seed": seed,
                    "act_id": act_id,
                    "activity": act_name,
                    "variant": variant,
                    "MAE_mean": float(np.nanmean(maes)),
                    "MAE_std": float(np.nanstd(maes)),
                    "MAPE_mean(%)": float(np.nanmean(mapes)),
                    "MAPE_std(%)": float(np.nanstd(mapes)),
                    "n_folds": int(np.sum(~np.isnan(maes))),
                }
                all_records.append(rec)

            # Print quick compare (Trial-only vs Ours) for this activity
            def _get(v, key):
                arr = np.array(fold_metrics[v][key], dtype=np.float32)
                return float(np.nanmean(arr)), float(np.nanstd(arr))

            t_mae_m, t_mae_s = _get("trial_only", "mae")
            o_mae_m, o_mae_s = _get("ours_window_proxy", "mae")
            t_mape_m, t_mape_s = _get("trial_only", "mape")
            o_mape_m, o_mape_s = _get("ours_window_proxy", "mape")

            print("\n" + "-" * 90)
            print(f"[Activity Summary] {act_id} {act_name}")
            print(f"  Trial-only       : MAE {t_mae_m:.3f} ± {t_mae_s:.3f} | MAPE {t_mape_m:.2f}% ± {t_mape_s:.2f}%")
            print(f"  Ours (win-proxy)  : MAE {o_mae_m:.3f} ± {o_mae_s:.3f} | MAPE {o_mape_m:.2f}% ± {o_mape_s:.2f}%")
            print("-" * 90)

    # Final summary table
    df = pd.DataFrame(all_records)
    if len(df) > 0:
        print("\n" + "=" * 90)
        print("FINAL SUMMARY (per seed, per activity, per variant)")
        print("=" * 90)
        with pd.option_context("display.max_rows", 200, "display.max_columns", 50):
            print(df.sort_values(["seed", "act_id", "variant"]).to_string(index=False))
    else:
        print("[No results] Check GT_LABELS_BY_ACT and activity mappings.")


if __name__ == "__main__":
    main()
# Out:
# Device: cuda
# Loading 10 subjects from /content/drive/MyDrive/Colab Notebooks/HAR_data/MHEALTHDATASET...
#
# ==========================================================================================
# SEED = 42
# ==========================================================================================
#
# ------------------------------------------------------------------------------------------
# ACTIVITY 6: Waist bends forward
# ------------------------------------------------------------------------------------------
#
# [Fold  1 | Test=subject1 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7587 | mae=2.672
#   [train] step   100/200 | loss=0.5067 | mae=1.609
#   [train] step   150/200 | loss=0.3993 | mae=1.221
#   [train] step   200/200 | loss=0.3380 | mae=1.017
# [Fold  1 | trial_only]  MAE=2.070 | MAPE=9.86%
#
# [Fold  1 | Test=subject1 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.5937 | mae=0.783
#   [train] step   100/200 | loss=0.4017 | mae=0.535
#   [train] step   150/200 | loss=0.3181 | mae=0.435
#   [train] step   200/200 | loss=0.2705 | mae=0.380
# [Fold  1 | ours_window_proxy]  MAE=2.551 | MAPE=12.15%
#
# [Fold  2 | Test=subject2 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7439 | mae=2.516
#   [train] step   100/200 | loss=0.4994 | mae=1.525
#   [train] step   150/200 | loss=0.3945 | mae=1.163
#   [train] step   200/200 | loss=0.3343 | mae=0.977
# [Fold  2 | trial_only]  MAE=3.059 | MAPE=16.10%
#
# [Fold  2 | Test=subject2 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.6039 | mae=0.793
#   [train] step   100/200 | loss=0.4132 | mae=0.539
#   [train] step   150/200 | loss=0.3290 | mae=0.444
#   [train] step   200/200 | loss=0.2807 | mae=0.390
# [Fold  2 | ours_window_proxy]  MAE=0.664 | MAPE=3.50%
#
# [Fold  3 | Test=subject3 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7608 | mae=2.575
#   [train] step   100/200 | loss=0.5087 | mae=1.544
#   [train] step   150/200 | loss=0.4005 | mae=1.163
#   [train] step   200/200 | loss=0.3389 | mae=0.969
# [Fold  3 | trial_only]  MAE=1.180 | MAPE=5.62%
#
# [Fold  3 | Test=subject3 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.6046 | mae=0.742
#   [train] step   100/200 | loss=0.4127 | mae=0.505
#   [train] step   150/200 | loss=0.3283 | mae=0.411
#   [train] step   200/200 | loss=0.2800 | mae=0.358
# [Fold  3 | ours_window_proxy]  MAE=2.227 | MAPE=10.60%
#
# [Fold  4 | Test=subject4 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7585 | mae=2.613
#   [train] step   100/200 | loss=0.5069 | mae=1.572
#   [train] step   150/200 | loss=0.3990 | mae=1.187
#   [train] step   200/200 | loss=0.3375 | mae=0.989
# [Fold  4 | trial_only]  MAE=0.761 | MAPE=3.80%
#
# [Fold  4 | Test=subject4 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.6088 | mae=0.778
#   [train] step   100/200 | loss=0.4119 | mae=0.542
#   [train] step   150/200 | loss=0.3262 | mae=0.445
#   [train] step   200/200 | loss=0.2774 | mae=0.387
# [Fold  4 | ours_window_proxy]  MAE=1.761 | MAPE=8.81%
#
# [Fold  5 | Test=subject5 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7631 | mae=2.524
#   [train] step   100/200 | loss=0.5090 | mae=1.501
#   [train] step   150/200 | loss=0.4013 | mae=1.119
#   [train] step   200/200 | loss=0.3397 | mae=0.913
# [Fold  5 | trial_only]  MAE=6.788 | MAPE=33.94%
#
# [Fold  5 | Test=subject5 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.6114 | mae=0.901
#   [train] step   100/200 | loss=0.4112 | mae=0.588
#   [train] step   150/200 | loss=0.3247 | mae=0.467
#   [train] step   200/200 | loss=0.2757 | mae=0.401
# [Fold  5 | ours_window_proxy]  MAE=0.813 | MAPE=4.07%
#
# [Fold  6 | Test=subject6 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7673 | mae=2.509
#   [train] step   100/200 | loss=0.5152 | mae=1.543
#   [train] step   150/200 | loss=0.4063 | mae=1.175
#   [train] step   200/200 | loss=0.3439 | mae=0.985
# [Fold  6 | trial_only]  MAE=4.980 | MAPE=24.90%
#
# [Fold  6 | Test=subject6 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.6136 | mae=0.853
#   [train] step   100/200 | loss=0.4143 | mae=0.579
#   [train] step   150/200 | loss=0.3277 | mae=0.474
#   [train] step   200/200 | loss=0.2784 | mae=0.414
# [Fold  6 | ours_window_proxy]  MAE=6.761 | MAPE=33.80%
#
# [Fold  7 | Test=subject7 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7752 | mae=2.581
#   [train] step   100/200 | loss=0.5170 | mae=1.532
#   [train] step   150/200 | loss=0.4076 | mae=1.127
#   [train] step   200/200 | loss=0.3450 | mae=0.918
# [Fold  7 | trial_only]  MAE=21.629 | MAPE=108.15%
#
# [Fold  7 | Test=subject7 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.6139 | mae=0.727
#   [train] step   100/200 | loss=0.4160 | mae=0.512
#   [train] step   150/200 | loss=0.3294 | mae=0.423
#   [train] step   200/200 | loss=0.2799 | mae=0.370
# [Fold  7 | ours_window_proxy]  MAE=0.602 | MAPE=3.01%
#
# [Fold  8 | Test=subject8 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7637 | mae=2.526
#   [train] step   100/200 | loss=0.5101 | mae=1.519
#   [train] step   150/200 | loss=0.4021 | mae=1.144
#   [train] step   200/200 | loss=0.3406 | mae=0.945
# [Fold  8 | trial_only]  MAE=6.230 | MAPE=29.67%
#
# [Fold  8 | Test=subject8 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.6070 | mae=0.733
#   [train] step   100/200 | loss=0.4150 | mae=0.513
#   [train] step   150/200 | loss=0.3295 | mae=0.428
#   [train] step   200/200 | loss=0.2803 | mae=0.376
# [Fold  8 | ours_window_proxy]  MAE=5.970 | MAPE=28.43%
#
# [Fold  9 | Test=subject9 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7897 | mae=2.649
#   [train] step   100/200 | loss=0.5309 | mae=1.645
#   [train] step   150/200 | loss=0.4181 | mae=1.264
#   [train] step   200/200 | loss=0.3532 | mae=1.065
# [Fold  9 | trial_only]  MAE=7.117 | MAPE=33.89%
#
# [Fold  9 | Test=subject9 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.6246 | mae=0.686
#   [train] step   100/200 | loss=0.4270 | mae=0.485
#   [train] step   150/200 | loss=0.3389 | mae=0.407
#   [train] step   200/200 | loss=0.2883 | mae=0.361
# [Fold  9 | ours_window_proxy]  MAE=2.495 | MAPE=11.88%
#
# [Fold 10 | Test=subject10 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7749 | mae=2.694
#   [train] step   100/200 | loss=0.5217 | mae=1.653
#   [train] step   150/200 | loss=0.4120 | mae=1.254
#   [train] step   200/200 | loss=0.3485 | mae=1.044
# [Fold 10 | trial_only]  MAE=2.810 | MAPE=14.05%
#
# [Fold 10 | Test=subject10 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.6143 | mae=0.766
#   [train] step   100/200 | loss=0.4163 | mae=0.536
#   [train] step   150/200 | loss=0.3293 | mae=0.440
#   [train] step   200/200 | loss=0.2798 | mae=0.386
# [Fold 10 | ours_window_proxy]  MAE=1.411 | MAPE=7.06%
#
# ------------------------------------------------------------------------------------------
# [Activity Summary] 6 Waist bends forward
#   Trial-only       : MAE 5.662 ± 5.754 | MAPE 28.00% ± 28.74%
#   Ours (win-proxy)  : MAE 2.525 ± 2.045 | MAPE 12.33% ± 9.98%
# ------------------------------------------------------------------------------------------
#
# ------------------------------------------------------------------------------------------
# ACTIVITY 7: Frontal elevation of arms
# ------------------------------------------------------------------------------------------
#
# [Fold  1 | Test=subject1 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8816 | mae=3.025
#   [train] step   100/200 | loss=0.6170 | mae=2.113
#   [train] step   150/200 | loss=0.4955 | mae=1.734
#   [train] step   200/200 | loss=0.4231 | mae=1.529
# [Fold  1 | trial_only]  MAE=0.343 | MAPE=1.72%
#
# [Fold  1 | Test=subject1 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7190 | mae=0.723
#   [train] step   100/200 | loss=0.5161 | mae=0.517
#   [train] step   150/200 | loss=0.4165 | mae=0.431
#   [train] step   200/200 | loss=0.3563 | mae=0.383
# [Fold  1 | ours_window_proxy]  MAE=1.966 | MAPE=9.83%
#
# [Fold  2 | Test=subject2 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8970 | mae=2.832
#   [train] step   100/200 | loss=0.6278 | mae=2.058
#   [train] step   150/200 | loss=0.5034 | mae=1.737
#   [train] step   200/200 | loss=0.4292 | mae=1.558
# [Fold  2 | trial_only]  MAE=4.955 | MAPE=24.78%
#
# [Fold  2 | Test=subject2 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7280 | mae=0.679
#   [train] step   100/200 | loss=0.5239 | mae=0.503
#   [train] step   150/200 | loss=0.4221 | mae=0.426
#   [train] step   200/200 | loss=0.3602 | mae=0.383
# [Fold  2 | ours_window_proxy]  MAE=4.023 | MAPE=20.12%
#
# [Fold  3 | Test=subject3 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8761 | mae=2.840
#   [train] step   100/200 | loss=0.6144 | mae=1.998
#   [train] step   150/200 | loss=0.4950 | mae=1.673
#   [train] step   200/200 | loss=0.4243 | mae=1.487
# [Fold  3 | trial_only]  MAE=7.196 | MAPE=35.98%
#
# [Fold  3 | Test=subject3 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7200 | mae=0.694
#   [train] step   100/200 | loss=0.5162 | mae=0.501
#   [train] step   150/200 | loss=0.4164 | mae=0.411
#   [train] step   200/200 | loss=0.3564 | mae=0.362
# [Fold  3 | ours_window_proxy]  MAE=3.490 | MAPE=17.45%
#
# [Fold  4 | Test=subject4 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8769 | mae=2.891
#   [train] step   100/200 | loss=0.6149 | mae=2.038
#   [train] step   150/200 | loss=0.4952 | mae=1.720
#   [train] step   200/200 | loss=0.4239 | mae=1.542
# [Fold  4 | trial_only]  MAE=1.070 | MAPE=5.35%
#
# [Fold  4 | Test=subject4 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7202 | mae=0.717
#   [train] step   100/200 | loss=0.5175 | mae=0.522
#   [train] step   150/200 | loss=0.4190 | mae=0.438
#   [train] step   200/200 | loss=0.3592 | mae=0.394
# [Fold  4 | ours_window_proxy]  MAE=1.473 | MAPE=7.37%
#
# [Fold  5 | Test=subject5 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8817 | mae=2.912
#   [train] step   100/200 | loss=0.6174 | mae=2.039
#   [train] step   150/200 | loss=0.4957 | mae=1.678
#   [train] step   200/200 | loss=0.4233 | mae=1.472
# [Fold  5 | trial_only]  MAE=1.767 | MAPE=8.84%
#
# [Fold  5 | Test=subject5 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7191 | mae=0.693
#   [train] step   100/200 | loss=0.5154 | mae=0.491
#   [train] step   150/200 | loss=0.4153 | mae=0.410
#   [train] step   200/200 | loss=0.3548 | mae=0.365
# [Fold  5 | ours_window_proxy]  MAE=1.248 | MAPE=6.24%
#
# [Fold  6 | Test=subject6 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8759 | mae=2.564
#   [train] step   100/200 | loss=0.6122 | mae=1.749
#   [train] step   150/200 | loss=0.4917 | mae=1.365
#   [train] step   200/200 | loss=0.4202 | mae=1.174
# [Fold  6 | trial_only]  MAE=7.842 | MAPE=39.21%
#
# [Fold  6 | Test=subject6 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7139 | mae=0.661
#   [train] step   100/200 | loss=0.5116 | mae=0.484
#   [train] step   150/200 | loss=0.4121 | mae=0.410
#   [train] step   200/200 | loss=0.3519 | mae=0.369
# [Fold  6 | ours_window_proxy]  MAE=7.190 | MAPE=35.95%
#
# [Fold  7 | Test=subject7 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8736 | mae=2.832
#   [train] step   100/200 | loss=0.6121 | mae=1.921
#   [train] step   150/200 | loss=0.4918 | mae=1.592
#   [train] step   200/200 | loss=0.4204 | mae=1.417
# [Fold  7 | trial_only]  MAE=1.260 | MAPE=6.30%
#
# [Fold  7 | Test=subject7 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7135 | mae=0.683
#   [train] step   100/200 | loss=0.5123 | mae=0.509
#   [train] step   150/200 | loss=0.4135 | mae=0.432
#   [train] step   200/200 | loss=0.3537 | mae=0.389
# [Fold  7 | ours_window_proxy]  MAE=6.702 | MAPE=33.51%
#
# [Fold  8 | Test=subject8 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8867 | mae=2.910
#   [train] step   100/200 | loss=0.6217 | mae=2.004
#   [train] step   150/200 | loss=0.4996 | mae=1.636
#   [train] step   200/200 | loss=0.4266 | mae=1.446
# [Fold  8 | trial_only]  MAE=2.123 | MAPE=11.17%
#
# [Fold  8 | Test=subject8 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7234 | mae=0.708
#   [train] step   100/200 | loss=0.5182 | mae=0.505
#   [train] step   150/200 | loss=0.4178 | mae=0.418
#   [train] step   200/200 | loss=0.3569 | mae=0.372
# [Fold  8 | ours_window_proxy]  MAE=0.464 | MAPE=2.44%
#
# [Fold  9 | Test=subject9 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8788 | mae=2.928
#   [train] step   100/200 | loss=0.6144 | mae=2.036
#   [train] step   150/200 | loss=0.4940 | mae=1.703
#   [train] step   200/200 | loss=0.4228 | mae=1.506
# [Fold  9 | trial_only]  MAE=1.755 | MAPE=9.23%
#
# [Fold  9 | Test=subject9 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7147 | mae=0.696
#   [train] step   100/200 | loss=0.5103 | mae=0.502
#   [train] step   150/200 | loss=0.4104 | mae=0.419
#   [train] step   200/200 | loss=0.3502 | mae=0.374
# [Fold  9 | ours_window_proxy]  MAE=1.276 | MAPE=6.72%
#
# [Fold 10 | Test=subject10 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8815 | mae=2.983
#   [train] step   100/200 | loss=0.6179 | mae=2.115
#   [train] step   150/200 | loss=0.4969 | mae=1.760
#   [train] step   200/200 | loss=0.4249 | mae=1.540
# [Fold 10 | trial_only]  MAE=0.582 | MAPE=2.91%
#
# [Fold 10 | Test=subject10 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7203 | mae=0.678
#   [train] step   100/200 | loss=0.5159 | mae=0.493
#   [train] step   150/200 | loss=0.4156 | mae=0.413
#   [train] step   200/200 | loss=0.3551 | mae=0.370
# [Fold 10 | ours_window_proxy]  MAE=1.287 | MAPE=6.43%
#
# ------------------------------------------------------------------------------------------
# [Activity Summary] 7 Frontal elevation of arms
#   Trial-only       : MAE 2.889 ± 2.613 | MAPE 14.55% ± 13.03%
#   Ours (win-proxy)  : MAE 2.912 ± 2.265 | MAPE 14.61% ± 11.29%
# ------------------------------------------------------------------------------------------
#
# ------------------------------------------------------------------------------------------
# ACTIVITY 8: Knees bending
# ------------------------------------------------------------------------------------------
#
# [Fold  1 | Test=subject1 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7481 | mae=2.664
#   [train] step   100/200 | loss=0.4940 | mae=1.781
#   [train] step   150/200 | loss=0.3893 | mae=1.404
#   [train] step   200/200 | loss=0.3299 | mae=1.193
# [Fold  1 | trial_only]  MAE=8.758 | MAPE=43.79%
#
# [Fold  1 | Test=subject1 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.5522 | mae=0.617
#   [train] step   100/200 | loss=0.3732 | mae=0.434
#   [train] step   150/200 | loss=0.2963 | mae=0.363
#   [train] step   200/200 | loss=0.2523 | mae=0.323
# [Fold  1 | ours_window_proxy]  MAE=0.952 | MAPE=4.76%
#
# [Fold  2 | Test=subject2 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7489 | mae=3.025
#   [train] step   100/200 | loss=0.4995 | mae=1.990
#   [train] step   150/200 | loss=0.3951 | mae=1.511
#   [train] step   200/200 | loss=0.3353 | mae=1.256
# [Fold  2 | trial_only]  MAE=1.256 | MAPE=5.98%
#
# [Fold  2 | Test=subject2 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.5830 | mae=0.667
#   [train] step   100/200 | loss=0.3954 | mae=0.483
#   [train] step   150/200 | loss=0.3131 | mae=0.407
#   [train] step   200/200 | loss=0.2658 | mae=0.359
# [Fold  2 | ours_window_proxy]  MAE=3.368 | MAPE=16.04%
#
# [Fold  3 | Test=subject3 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7708 | mae=2.763
#   [train] step   100/200 | loss=0.5157 | mae=1.846
#   [train] step   150/200 | loss=0.4073 | mae=1.464
#   [train] step   200/200 | loss=0.3454 | mae=1.253
# [Fold  3 | trial_only]  MAE=3.769 | MAPE=17.95%
#
# [Fold  3 | Test=subject3 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.5956 | mae=0.657
#   [train] step   100/200 | loss=0.4060 | mae=0.469
#   [train] step   150/200 | loss=0.3219 | mae=0.393
#   [train] step   200/200 | loss=0.2733 | mae=0.349
# [Fold  3 | ours_window_proxy]  MAE=0.550 | MAPE=2.62%
#
# [Fold  4 | Test=subject4 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7689 | mae=2.620
#   [train] step   100/200 | loss=0.5137 | mae=1.732
#   [train] step   150/200 | loss=0.4052 | mae=1.361
#   [train] step   200/200 | loss=0.3432 | mae=1.128
# [Fold  4 | trial_only]  MAE=6.533 | MAPE=34.39%
#
# [Fold  4 | Test=subject4 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.5934 | mae=0.648
#   [train] step   100/200 | loss=0.4048 | mae=0.470
#   [train] step   150/200 | loss=0.3213 | mae=0.395
#   [train] step   200/200 | loss=0.2731 | mae=0.348
# [Fold  4 | ours_window_proxy]  MAE=1.095 | MAPE=5.76%
#
# [Fold  5 | Test=subject5 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7709 | mae=3.039
#   [train] step   100/200 | loss=0.5124 | mae=1.891
#   [train] step   150/200 | loss=0.4038 | mae=1.410
#   [train] step   200/200 | loss=0.3417 | mae=1.176
# [Fold  5 | trial_only]  MAE=1.603 | MAPE=8.01%
#
# [Fold  5 | Test=subject5 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.5804 | mae=0.652
#   [train] step   100/200 | loss=0.3946 | mae=0.467
#   [train] step   150/200 | loss=0.3126 | mae=0.402
#   [train] step   200/200 | loss=0.2656 | mae=0.365
# [Fold  5 | ours_window_proxy]  MAE=3.863 | MAPE=19.32%
#
# [Fold  6 | Test=subject6 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7779 | mae=2.962
#   [train] step   100/200 | loss=0.5182 | mae=1.890
#   [train] step   150/200 | loss=0.4081 | mae=1.465
#   [train] step   200/200 | loss=0.3450 | mae=1.229
# [Fold  6 | trial_only]  MAE=6.472 | MAPE=32.36%
#
# [Fold  6 | Test=subject6 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.5825 | mae=0.651
#   [train] step   100/200 | loss=0.3975 | mae=0.466
#   [train] step   150/200 | loss=0.3154 | mae=0.394
#   [train] step   200/200 | loss=0.2679 | mae=0.349
# [Fold  6 | ours_window_proxy]  MAE=2.628 | MAPE=13.14%
#
# [Fold  7 | Test=subject7 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7745 | mae=3.004
#   [train] step   100/200 | loss=0.5156 | mae=1.847
#   [train] step   150/200 | loss=0.4065 | mae=1.426
#   [train] step   200/200 | loss=0.3440 | mae=1.205
# [Fold  7 | trial_only]  MAE=2.420 | MAPE=11.53%
#
# [Fold  7 | Test=subject7 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.5791 | mae=0.660
#   [train] step   100/200 | loss=0.3943 | mae=0.454
#   [train] step   150/200 | loss=0.3129 | mae=0.364
#   [train] step   200/200 | loss=0.2657 | mae=0.310
# [Fold  7 | ours_window_proxy]  MAE=0.046 | MAPE=0.22%
#
# [Fold  8 | Test=subject8 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7745 | mae=2.949
#   [train] step   100/200 | loss=0.5145 | mae=1.852
#   [train] step   150/200 | loss=0.4049 | mae=1.464
#   [train] step   200/200 | loss=0.3420 | mae=1.249
# [Fold  8 | trial_only]  MAE=3.571 | MAPE=17.01%
#
# [Fold  8 | Test=subject8 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.5867 | mae=0.670
#   [train] step   100/200 | loss=0.4013 | mae=0.483
#   [train] step   150/200 | loss=0.3185 | mae=0.411
#   [train] step   200/200 | loss=0.2707 | mae=0.371
# [Fold  8 | ours_window_proxy]  MAE=4.780 | MAPE=22.76%
#
# [Fold  9 | Test=subject9 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7842 | mae=2.665
#   [train] step   100/200 | loss=0.5235 | mae=1.657
#   [train] step   150/200 | loss=0.4134 | mae=1.305
#   [train] step   200/200 | loss=0.3499 | mae=1.103
# [Fold  9 | trial_only]  MAE=2.981 | MAPE=14.20%
#
# [Fold  9 | Test=subject9 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.5811 | mae=0.680
#   [train] step   100/200 | loss=0.3948 | mae=0.489
#   [train] step   150/200 | loss=0.3129 | mae=0.418
#   [train] step   200/200 | loss=0.2659 | mae=0.379
# [Fold  9 | ours_window_proxy]  MAE=1.512 | MAPE=7.20%
#
# [Fold 10 | Test=subject10 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.7847 | mae=2.926
#   [train] step   100/200 | loss=0.5233 | mae=1.841
#   [train] step   150/200 | loss=0.4128 | mae=1.404
#   [train] step   200/200 | loss=0.3492 | mae=1.173
# [Fold 10 | trial_only]  MAE=1.582 | MAPE=7.53%
#
# [Fold 10 | Test=subject10 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.5809 | mae=0.665
#   [train] step   100/200 | loss=0.3949 | mae=0.482
#   [train] step   150/200 | loss=0.3125 | mae=0.409
#   [train] step   200/200 | loss=0.2652 | mae=0.369
# [Fold 10 | ours_window_proxy]  MAE=3.584 | MAPE=17.07%
#
# ------------------------------------------------------------------------------------------
# [Activity Summary] 8 Knees bending
#   Trial-only       : MAE 3.895 ± 2.407 | MAPE 19.27% ± 12.39%
#   Ours (win-proxy)  : MAE 2.238 ± 1.532 | MAPE 10.89% ± 7.36%
# ------------------------------------------------------------------------------------------
#
# ------------------------------------------------------------------------------------------
# ACTIVITY 10: Jogging
# ------------------------------------------------------------------------------------------
#
# [Fold  1 | Test=subject1 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.1896 | mae=11.990
#   [train] step   100/200 | loss=0.7778 | mae=6.307
#   [train] step   150/200 | loss=0.6082 | mae=4.276
#   [train] step   200/200 | loss=0.5126 | mae=3.239
# [Fold  1 | trial_only]  MAE=2.569 | MAPE=1.64%
#
# [Fold  1 | Test=subject1 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0751 | mae=2.862
#   [train] step   100/200 | loss=0.7096 | mae=1.779
#   [train] step   150/200 | loss=0.5577 | mae=1.378
#   [train] step   200/200 | loss=0.4728 | mae=1.164
# [Fold  1 | ours_window_proxy]  MAE=0.483 | MAPE=0.31%
#
# [Fold  2 | Test=subject2 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.2419 | mae=15.202
#   [train] step   100/200 | loss=0.8129 | mae=7.976
#   [train] step   150/200 | loss=0.6370 | mae=5.406
#   [train] step   200/200 | loss=0.5380 | mae=4.115
# [Fold  2 | trial_only]  MAE=4.699 | MAPE=2.92%
#
# [Fold  2 | Test=subject2 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0863 | mae=2.854
#   [train] step   100/200 | loss=0.7189 | mae=1.750
#   [train] step   150/200 | loss=0.5656 | mae=1.339
#   [train] step   200/200 | loss=0.4798 | mae=1.122
# [Fold  2 | ours_window_proxy]  MAE=9.563 | MAPE=5.94%
#
# [Fold  3 | Test=subject3 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.2186 | mae=11.525
#   [train] step   100/200 | loss=0.7947 | mae=6.041
#   [train] step   150/200 | loss=0.6197 | mae=4.086
#   [train] step   200/200 | loss=0.5214 | mae=3.109
# [Fold  3 | trial_only]  MAE=2.319 | MAPE=1.51%
#
# [Fold  3 | Test=subject3 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.1025 | mae=2.897
#   [train] step   100/200 | loss=0.7337 | mae=1.798
#   [train] step   150/200 | loss=0.5786 | mae=1.384
#   [train] step   200/200 | loss=0.4916 | mae=1.163
# [Fold  3 | ours_window_proxy]  MAE=8.576 | MAPE=5.57%
#
# [Fold  4 | Test=subject4 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.2263 | mae=11.683
#   [train] step   100/200 | loss=0.8024 | mae=6.122
#   [train] step   150/200 | loss=0.6266 | mae=4.141
#   [train] step   200/200 | loss=0.5277 | mae=3.150
# [Fold  4 | trial_only]  MAE=0.951 | MAPE=0.62%
#
# [Fold  4 | Test=subject4 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.1120 | mae=2.912
#   [train] step   100/200 | loss=0.7412 | mae=1.802
#   [train] step   150/200 | loss=0.5853 | mae=1.387
#   [train] step   200/200 | loss=0.4976 | mae=1.164
# [Fold  4 | ours_window_proxy]  MAE=6.804 | MAPE=4.42%
#
# [Fold  5 | Test=subject5 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.2392 | mae=13.358
#   [train] step   100/200 | loss=0.8124 | mae=7.075
#   [train] step   150/200 | loss=0.6351 | mae=4.807
#   [train] step   200/200 | loss=0.5352 | mae=3.662
# [Fold  5 | trial_only]  MAE=4.063 | MAPE=2.54%
#
# [Fold  5 | Test=subject5 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0976 | mae=2.830
#   [train] step   100/200 | loss=0.7301 | mae=1.767
#   [train] step   150/200 | loss=0.5746 | mae=1.369
#   [train] step   200/200 | loss=0.4876 | mae=1.156
# [Fold  5 | ours_window_proxy]  MAE=2.072 | MAPE=1.29%
#
# [Fold  6 | Test=subject6 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.2114 | mae=12.688
#   [train] step   100/200 | loss=0.7923 | mae=6.670
#   [train] step   150/200 | loss=0.6183 | mae=4.505
#   [train] step   200/200 | loss=0.5209 | mae=3.415
# [Fold  6 | trial_only]  MAE=31.344 | MAPE=20.09%
#
# [Fold  6 | Test=subject6 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0792 | mae=2.879
#   [train] step   100/200 | loss=0.7171 | mae=1.784
#   [train] step   150/200 | loss=0.5670 | mae=1.377
#   [train] step   200/200 | loss=0.4829 | mae=1.162
# [Fold  6 | ours_window_proxy]  MAE=2.068 | MAPE=1.33%
#
# [Fold  7 | Test=subject7 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.2355 | mae=12.803
#   [train] step   100/200 | loss=0.8124 | mae=6.700
#   [train] step   150/200 | loss=0.6367 | mae=4.540
#   [train] step   200/200 | loss=0.5376 | mae=3.450
# [Fold  7 | trial_only]  MAE=12.567 | MAPE=8.21%
#
# [Fold  7 | Test=subject7 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.1048 | mae=2.850
#   [train] step   100/200 | loss=0.7356 | mae=1.764
#   [train] step   150/200 | loss=0.5801 | mae=1.362
#   [train] step   200/200 | loss=0.4929 | mae=1.149
# [Fold  7 | ours_window_proxy]  MAE=0.203 | MAPE=0.13%
#
# [Fold  8 | Test=subject8 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.2240 | mae=14.148
#   [train] step   100/200 | loss=0.7979 | mae=7.506
#   [train] step   150/200 | loss=0.6231 | mae=5.104
#   [train] step   200/200 | loss=0.5252 | mae=3.901
# [Fold  8 | trial_only]  MAE=10.938 | MAPE=6.84%
#
# [Fold  8 | Test=subject8 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0784 | mae=2.814
#   [train] step   100/200 | loss=0.7153 | mae=1.750
#   [train] step   150/200 | loss=0.5630 | mae=1.354
#   [train] step   200/200 | loss=0.4778 | mae=1.143
# [Fold  8 | ours_window_proxy]  MAE=15.733 | MAPE=9.83%
#
# [Fold  9 | Test=subject9 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.2479 | mae=14.031
#   [train] step   100/200 | loss=0.8210 | mae=7.475
#   [train] step   150/200 | loss=0.6420 | mae=5.084
#   [train] step   200/200 | loss=0.5411 | mae=3.889
# [Fold  9 | trial_only]  MAE=8.216 | MAPE=4.95%
#
# [Fold  9 | Test=subject9 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0914 | mae=2.812
#   [train] step   100/200 | loss=0.7266 | mae=1.747
#   [train] step   150/200 | loss=0.5728 | mae=1.352
#   [train] step   200/200 | loss=0.4868 | mae=1.142
# [Fold  9 | ours_window_proxy]  MAE=5.548 | MAPE=3.34%
#
# [Fold 10 | Test=subject10 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.2335 | mae=13.158
#   [train] step   100/200 | loss=0.8074 | mae=6.905
#   [train] step   150/200 | loss=0.6311 | mae=4.667
#   [train] step   200/200 | loss=0.5320 | mae=3.544
# [Fold 10 | trial_only]  MAE=15.680 | MAPE=10.05%
#
# [Fold 10 | Test=subject10 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0777 | mae=2.784
#   [train] step   100/200 | loss=0.7184 | mae=1.729
#   [train] step   150/200 | loss=0.5671 | mae=1.332
#   [train] step   200/200 | loss=0.4823 | mae=1.120
# [Fold 10 | ours_window_proxy]  MAE=9.547 | MAPE=6.12%
#
# ------------------------------------------------------------------------------------------
# [Activity Summary] 10 Jogging
#   Trial-only       : MAE 9.335 ± 8.681 | MAPE 5.94% ± 5.58%
#   Ours (win-proxy)  : MAE 6.060 ± 4.716 | MAPE 3.83% ± 2.97%
# ------------------------------------------------------------------------------------------
#
# ------------------------------------------------------------------------------------------
# ACTIVITY 11: Running
# ------------------------------------------------------------------------------------------
#
# [Fold  1 | Test=subject1 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.3342 | mae=18.294
#   [train] step   100/200 | loss=0.8758 | mae=9.708
#   [train] step   150/200 | loss=0.6874 | mae=6.606
#   [train] step   200/200 | loss=0.5813 | mae=5.035
# [Fold  1 | trial_only]  MAE=8.114 | MAPE=4.92%
#
# [Fold  1 | Test=subject1 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0797 | mae=2.584
#   [train] step   100/200 | loss=0.7295 | mae=1.573
#   [train] step   150/200 | loss=0.5795 | mae=1.197
#   [train] step   200/200 | loss=0.4942 | mae=0.998
# [Fold  1 | ours_window_proxy]  MAE=9.765 | MAPE=5.92%
#
# [Fold  2 | Test=subject2 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.3551 | mae=18.640
#   [train] step   100/200 | loss=0.8858 | mae=9.749
#   [train] step   150/200 | loss=0.6931 | mae=6.623
#   [train] step   200/200 | loss=0.5850 | mae=5.035
# [Fold  2 | trial_only]  MAE=1.416 | MAPE=0.90%
#
# [Fold  2 | Test=subject2 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.1057 | mae=2.729
#   [train] step   100/200 | loss=0.7427 | mae=1.680
#   [train] step   150/200 | loss=0.5880 | mae=1.280
#   [train] step   200/200 | loss=0.5007 | mae=1.065
# [Fold  2 | ours_window_proxy]  MAE=8.391 | MAPE=5.31%
#
# [Fold  3 | Test=subject3 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.3152 | mae=16.462
#   [train] step   100/200 | loss=0.8670 | mae=8.649
#   [train] step   150/200 | loss=0.6800 | mae=5.842
#   [train] step   200/200 | loss=0.5737 | mae=4.443
# [Fold  3 | trial_only]  MAE=21.523 | MAPE=12.37%
#
# [Fold  3 | Test=subject3 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0831 | mae=2.561
#   [train] step   100/200 | loss=0.7349 | mae=1.580
#   [train] step   150/200 | loss=0.5850 | mae=1.209
#   [train] step   200/200 | loss=0.4996 | mae=1.011
# [Fold  3 | ours_window_proxy]  MAE=30.646 | MAPE=17.61%
#
# [Fold  4 | Test=subject4 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.3153 | mae=16.488
#   [train] step   100/200 | loss=0.8644 | mae=8.659
#   [train] step   150/200 | loss=0.6776 | mae=5.870
#   [train] step   200/200 | loss=0.5723 | mae=4.462
# [Fold  4 | trial_only]  MAE=12.190 | MAPE=7.48%
#
# [Fold  4 | Test=subject4 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0880 | mae=2.561
#   [train] step   100/200 | loss=0.7360 | mae=1.564
#   [train] step   150/200 | loss=0.5836 | mae=1.190
#   [train] step   200/200 | loss=0.4970 | mae=0.992
# [Fold  4 | ours_window_proxy]  MAE=8.563 | MAPE=5.25%
#
# [Fold  5 | Test=subject5 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.3384 | mae=17.288
#   [train] step   100/200 | loss=0.8823 | mae=9.105
#   [train] step   150/200 | loss=0.6928 | mae=6.206
#   [train] step   200/200 | loss=0.5854 | mae=4.735
# [Fold  5 | trial_only]  MAE=7.800 | MAPE=4.97%
#
# [Fold  5 | Test=subject5 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.1327 | mae=2.814
#   [train] step   100/200 | loss=0.7622 | mae=1.720
#   [train] step   150/200 | loss=0.6033 | mae=1.307
#   [train] step   200/200 | loss=0.5134 | mae=1.087
# [Fold  5 | ours_window_proxy]  MAE=1.062 | MAPE=0.68%
#
# [Fold  6 | Test=subject6 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.3307 | mae=18.409
#   [train] step   100/200 | loss=0.8774 | mae=9.958
#   [train] step   150/200 | loss=0.6924 | mae=6.825
#   [train] step   200/200 | loss=0.5879 | mae=5.227
# [Fold  6 | trial_only]  MAE=18.223 | MAPE=10.59%
#
# [Fold  6 | Test=subject6 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0686 | mae=2.540
#   [train] step   100/200 | loss=0.7264 | mae=1.578
#   [train] step   150/200 | loss=0.5783 | mae=1.210
#   [train] step   200/200 | loss=0.4937 | mae=1.013
# [Fold  6 | ours_window_proxy]  MAE=22.941 | MAPE=13.34%
#
# [Fold  7 | Test=subject7 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.3464 | mae=17.368
#   [train] step   100/200 | loss=0.8899 | mae=9.232
#   [train] step   150/200 | loss=0.7000 | mae=6.288
#   [train] step   200/200 | loss=0.5917 | mae=4.802
# [Fold  7 | trial_only]  MAE=19.120 | MAPE=12.83%
#
# [Fold  7 | Test=subject7 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.1257 | mae=2.781
#   [train] step   100/200 | loss=0.7589 | mae=1.696
#   [train] step   150/200 | loss=0.6016 | mae=1.285
#   [train] step   200/200 | loss=0.5124 | mae=1.066
# [Fold  7 | ours_window_proxy]  MAE=13.994 | MAPE=9.39%
#
# [Fold  8 | Test=subject8 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.3174 | mae=17.988
#   [train] step   100/200 | loss=0.8634 | mae=9.573
#   [train] step   150/200 | loss=0.6771 | mae=6.552
#   [train] step   200/200 | loss=0.5721 | mae=5.023
# [Fold  8 | trial_only]  MAE=6.322 | MAPE=3.81%
#
# [Fold  8 | Test=subject8 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0324 | mae=2.445
#   [train] step   100/200 | loss=0.6989 | mae=1.507
#   [train] step   150/200 | loss=0.5559 | mae=1.150
#   [train] step   200/200 | loss=0.4748 | mae=0.961
# [Fold  8 | ours_window_proxy]  MAE=40.764 | MAPE=24.56%
#
# [Fold  9 | Test=subject9 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.3171 | mae=17.045
#   [train] step   100/200 | loss=0.8710 | mae=9.066
#   [train] step   150/200 | loss=0.6860 | mae=6.199
#   [train] step   200/200 | loss=0.5809 | mae=4.743
# [Fold  9 | trial_only]  MAE=12.712 | MAPE=7.31%
#
# [Fold  9 | Test=subject9 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0620 | mae=2.485
#   [train] step   100/200 | loss=0.7210 | mae=1.550
#   [train] step   150/200 | loss=0.5732 | mae=1.189
#   [train] step   200/200 | loss=0.4890 | mae=0.995
# [Fold  9 | ours_window_proxy]  MAE=0.644 | MAPE=0.37%
#
# [Fold 10 | Test=subject10 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.3300 | mae=16.863
#   [train] step   100/200 | loss=0.8753 | mae=8.878
#   [train] step   150/200 | loss=0.6869 | mae=6.014
#   [train] step   200/200 | loss=0.5803 | mae=4.568
# [Fold 10 | trial_only]  MAE=21.100 | MAPE=12.27%
#
# [Fold 10 | Test=subject10 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0823 | mae=2.586
#   [train] step   100/200 | loss=0.7337 | mae=1.595
#   [train] step   150/200 | loss=0.5830 | mae=1.214
#   [train] step   200/200 | loss=0.4972 | mae=1.011
# [Fold 10 | ours_window_proxy]  MAE=1.860 | MAPE=1.08%
#
# ------------------------------------------------------------------------------------------
# [Activity Summary] 11 Running
#   Trial-only       : MAE 12.852 ± 6.582 | MAPE 7.74% ± 3.93%
#   Ours (win-proxy)  : MAE 13.863 ± 12.827 | MAPE 8.35% ± 7.58%
# ------------------------------------------------------------------------------------------
#
# ------------------------------------------------------------------------------------------
# ACTIVITY 12: Jump front & back
# ------------------------------------------------------------------------------------------
#
# [Fold  1 | Test=subject1 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0185 | mae=1.955
#   [train] step   100/200 | loss=0.7108 | mae=1.072
#   [train] step   150/200 | loss=0.5680 | mae=0.782
#   [train] step   200/200 | loss=0.4838 | mae=0.638
# [Fold  1 | trial_only]  MAE=0.567 | MAPE=2.84%
#
# [Fold  1 | Test=subject1 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8541 | mae=1.385
#   [train] step   100/200 | loss=0.6127 | mae=0.845
#   [train] step   150/200 | loss=0.4961 | mae=0.638
#   [train] step   200/200 | loss=0.4269 | mae=0.528
# [Fold  1 | ours_window_proxy]  MAE=0.180 | MAPE=0.90%
#
# [Fold  2 | Test=subject2 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0299 | mae=1.674
#   [train] step   100/200 | loss=0.7145 | mae=0.922
#   [train] step   150/200 | loss=0.5680 | mae=0.679
#   [train] step   200/200 | loss=0.4818 | mae=0.549
# [Fold  2 | trial_only]  MAE=3.068 | MAPE=13.95%
#
# [Fold  2 | Test=subject2 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8559 | mae=1.323
#   [train] step   100/200 | loss=0.6116 | mae=0.801
#   [train] step   150/200 | loss=0.4943 | mae=0.601
#   [train] step   200/200 | loss=0.4248 | mae=0.493
# [Fold  2 | ours_window_proxy]  MAE=3.649 | MAPE=16.59%
#
# [Fold  3 | Test=subject3 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0323 | mae=1.722
#   [train] step   100/200 | loss=0.7182 | mae=0.963
#   [train] step   150/200 | loss=0.5717 | mae=0.719
#   [train] step   200/200 | loss=0.4853 | mae=0.592
# [Fold  3 | trial_only]  MAE=2.061 | MAPE=9.81%
#
# [Fold  3 | Test=subject3 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8610 | mae=1.378
#   [train] step   100/200 | loss=0.6179 | mae=0.854
#   [train] step   150/200 | loss=0.5008 | mae=0.647
#   [train] step   200/200 | loss=0.4312 | mae=0.536
# [Fold  3 | ours_window_proxy]  MAE=0.179 | MAPE=0.85%
#
# [Fold  4 | Test=subject4 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0291 | mae=1.833
#   [train] step   100/200 | loss=0.7192 | mae=1.026
#   [train] step   150/200 | loss=0.5741 | mae=0.772
#   [train] step   200/200 | loss=0.4882 | mae=0.641
# [Fold  4 | trial_only]  MAE=1.310 | MAPE=6.24%
#
# [Fold  4 | Test=subject4 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8371 | mae=1.291
#   [train] step   100/200 | loss=0.6027 | mae=0.809
#   [train] step   150/200 | loss=0.4884 | mae=0.618
#   [train] step   200/200 | loss=0.4198 | mae=0.512
# [Fold  4 | ours_window_proxy]  MAE=1.830 | MAPE=8.71%
#
# [Fold  5 | Test=subject5 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0281 | mae=1.889
#   [train] step   100/200 | loss=0.7174 | mae=1.043
#   [train] step   150/200 | loss=0.5729 | mae=0.784
#   [train] step   200/200 | loss=0.4876 | mae=0.654
# [Fold  5 | trial_only]  MAE=3.144 | MAPE=15.72%
#
# [Fold  5 | Test=subject5 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8549 | mae=1.397
#   [train] step   100/200 | loss=0.6144 | mae=0.859
#   [train] step   150/200 | loss=0.4990 | mae=0.650
#   [train] step   200/200 | loss=0.4303 | mae=0.537
# [Fold  5 | ours_window_proxy]  MAE=0.557 | MAPE=2.78%
#
# [Fold  6 | Test=subject6 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0309 | mae=2.022
#   [train] step   100/200 | loss=0.7209 | mae=1.105
#   [train] step   150/200 | loss=0.5767 | mae=0.802
#   [train] step   200/200 | loss=0.4912 | mae=0.657
# [Fold  6 | trial_only]  MAE=0.632 | MAPE=3.01%
#
# [Fold  6 | Test=subject6 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8419 | mae=1.289
#   [train] step   100/200 | loss=0.6066 | mae=0.799
#   [train] step   150/200 | loss=0.4920 | mae=0.602
#   [train] step   200/200 | loss=0.4236 | mae=0.497
# [Fold  6 | ours_window_proxy]  MAE=3.802 | MAPE=18.11%
#
# [Fold  7 | Test=subject7 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0416 | mae=1.899
#   [train] step   100/200 | loss=0.7255 | mae=1.064
#   [train] step   150/200 | loss=0.5778 | mae=0.785
#   [train] step   200/200 | loss=0.4905 | mae=0.641
# [Fold  7 | trial_only]  MAE=1.234 | MAPE=6.50%
#
# [Fold  7 | Test=subject7 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8619 | mae=1.354
#   [train] step   100/200 | loss=0.6196 | mae=0.819
#   [train] step   150/200 | loss=0.5017 | mae=0.611
#   [train] step   200/200 | loss=0.4316 | mae=0.500
# [Fold  7 | ours_window_proxy]  MAE=1.769 | MAPE=9.31%
#
# [Fold  8 | Test=subject8 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0159 | mae=1.666
#   [train] step   100/200 | loss=0.7051 | mae=0.934
#   [train] step   150/200 | loss=0.5618 | mae=0.706
#   [train] step   200/200 | loss=0.4776 | mae=0.582
# [Fold  8 | trial_only]  MAE=0.148 | MAPE=0.74%
#
# [Fold  8 | Test=subject8 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8377 | mae=1.376
#   [train] step   100/200 | loss=0.6010 | mae=0.851
#   [train] step   150/200 | loss=0.4876 | mae=0.644
#   [train] step   200/200 | loss=0.4206 | mae=0.532
# [Fold  8 | ours_window_proxy]  MAE=1.499 | MAPE=7.49%
#
# [Fold  9 | Test=subject9 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0378 | mae=1.834
#   [train] step   100/200 | loss=0.7247 | mae=0.999
#   [train] step   150/200 | loss=0.5770 | mae=0.730
#   [train] step   200/200 | loss=0.4896 | mae=0.594
# [Fold  9 | trial_only]  MAE=2.142 | MAPE=10.71%
#
# [Fold  9 | Test=subject9 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8782 | mae=1.445
#   [train] step   100/200 | loss=0.6294 | mae=0.892
#   [train] step   150/200 | loss=0.5100 | mae=0.676
#   [train] step   200/200 | loss=0.4391 | mae=0.560
# [Fold  9 | ours_window_proxy]  MAE=0.574 | MAPE=2.87%
#
# [Fold 10 | Test=subject10 | trial_only] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=1.0373 | mae=1.889
#   [train] step   100/200 | loss=0.7248 | mae=1.054
#   [train] step   150/200 | loss=0.5786 | mae=0.785
#   [train] step   200/200 | loss=0.4921 | mae=0.652
# [Fold 10 | trial_only]  MAE=0.119 | MAPE=0.60%
#
# [Fold 10 | Test=subject10 | ours_window_proxy] TRAIN (fixed updates=200)
#   [train] step    50/200 | loss=0.8765 | mae=1.403
#   [train] step   100/200 | loss=0.6290 | mae=0.860
#   [train] step   150/200 | loss=0.5091 | mae=0.652
#   [train] step   200/200 | loss=0.4377 | mae=0.541
# [Fold 10 | ours_window_proxy]  MAE=1.515 | MAPE=7.58%
#
# ------------------------------------------------------------------------------------------
# [Activity Summary] 12 Jump front & back
#   Trial-only       : MAE 1.443 ± 1.064 | MAPE 7.01% ± 5.10%
#   Ours (win-proxy)  : MAE 1.555 ± 1.237 | MAPE 7.52% ± 5.76%
# ------------------------------------------------------------------------------------------
#
# ==========================================================================================
# FINAL SUMMARY (per seed, per activity, per variant)
# ==========================================================================================
#  seed  act_id                  activity           variant  MAE_mean   MAE_std  MAPE_mean(%)  MAPE_std(%)  n_folds
#    42       6       Waist bends forward ours_window_proxy  2.525486  2.044777     12.329615     9.984238       10
#    42       6       Waist bends forward        trial_only  5.662219  5.753696     27.996426    28.736008       10
#    42       7 Frontal elevation of arms ours_window_proxy  2.911965  2.264505     14.605619    11.285482       10
#    42       7 Frontal elevation of arms        trial_only  2.889336  2.612579     14.548719    13.028019       10
#    42       8             Knees bending ours_window_proxy  2.237835  1.532442     10.888448     7.357853       10
#    42       8             Knees bending        trial_only  3.894595  2.407445     19.273960    12.389187       10
#    42      10                   Jogging ours_window_proxy  6.059647  4.715871      3.828255     2.968436       10
#    42      10                   Jogging        trial_only  9.334631  8.680556      5.936087     5.579937       10
#    42      11                   Running ours_window_proxy 13.863011 12.826868      8.350939     7.579950       10
#    42      11                   Running        trial_only 12.852150  6.581545      7.743956     3.926821       10
#    42      12         Jump front & back ours_window_proxy  1.555424  1.237183      7.519420     5.755640       10
#    42      12         Jump front & back        trial_only  1.442599  1.064009      7.010703     5.101762       10
